# %% [markdown]
# # Content Dimension: text
# ### Features
# * BoW
# * TF-IDF
# * LDA

# %% [markdown]
# ### Load data

# %%
import pandas as pd

df_train = pd.read_csv('data/2018/train-test/train.csv')
df_test = pd.read_csv('data/2018/train-test/test.csv')

# %% [markdown]
# ### Preprocess

# %%
from utils import preprocess

# %%
df_train['preprocessed_text'] = [preprocess(t) for t in df_train['text']]

# %%
df_test['preprocessed_text'] = [preprocess(t) for t in df_test['text']]

# %% [markdown]
# # Binary Bag of Words

# %%
from sklearn.feature_extraction.text import CountVectorizer
bow = CountVectorizer(max_features = None, ngram_range = (1,2), #(1,3) 
                             lowercase = False, token_pattern = r'[^\s]+',binary=True)

bow.fit(df_train['preprocessed_text'])   
X_train = bow.transform(df_train['preprocessed_text'])
X_test = bow.transform(df_test['preprocessed_text'])

y_train = df_train['misinformation']
y_test = df_test['misinformation']


X_train.shape
# Out:
# (6233, 278363)

# %%
from sklearn.linear_model import LogisticRegression
import utils

print('logistic regression + binary bow')
clf = LogisticRegression()
clf.fit(X_train, y_train)

y_prob = clf.predict_proba(X_test)[:,1]
y_prob_train = clf.predict_proba(X_train)[:,1]
# threshold moving

thr = utils.optimal_threshold(y_prob_train, y_train)
print(thr)
y_pred = [1 if p >= thr else 0 for p in y_prob]
utils.get_test_metrics(y_test, y_pred, y_prob, full_metrics = True)
# Out:
# logistic regression + binary bow
# C:\Users\lucas.carneiro\Anaconda3\envs\env\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.38
#               precision    recall  f1-score   support
#
#            0       0.83      0.84      0.83       820
#            1       0.82      0.81      0.81       739
#
#     accuracy                           0.82      1559
#    macro avg       0.82      0.82      0.82      1559
# weighted avg       0.82      0.82      0.82      1559
#
# AUC:  0.9066685369154099
# (0.8236048749198204,
#  0.8186813186813187,
#  0.83343428225318,
#  0.8064952638700947,
#  0.83343428225318,
#  0.8125426039536469,
#  0.83343428225318,
#  0.9066685369154099)

# %%
df_test['pred'] = y_pred

# 1-1 = 0 TP
# 0-0 = 0 TN
# 1-0 = 1 FN
# 0-1 = -1 FP
df_test['error'] = df_test['misinformation'] - df_test['pred']
errors_expanded = df_test[(df_test['original']==0)&(df_test['error']!=0)]
n_errors_expanded = len(errors_expanded)
errors_expanded
# Out:
#                                                    text  misinformation  \
# 23    ❤REPASSANDO❤                     \n\nQuerido p...               0
# 25    *"Quando a então poderosíssima União Soviética...               0
# 26    *"Quando a então poderosíssima União Soviética...               0
# 45    *DILMA SE DESPEDE DA POLÍTICA*\n \nPrezados br...               0
# 46    *EX-PRESIDENTA DILMA SE DESPEDE DA POLÍTICA* 😔...               0
# ...                                                 ...             ...
# 1489  Frases marcantes da história:\n\n"A sorte está...               0
# 1490  Frases marcantes da história:\n\n"A sorte está...               0
# 1534  ATENÇÃO \nNos postos de Polícia rodoviária fed...               1
# 1543  Ladrão tenta roubar com faca dentro do trem, s...               0
# 1545  *_Vamos começar uma campanha, quem é brasileir...               0
#
#       original                                  preprocessed_text  pred  error
# 23           0  repassar \n \n querer povo brasileiro diretore...     1     -1
# 25           0  * entao poderoso uniao sovietico invadir peque...     1     -1
# 26           0  * entao poderoso uniao sovietico invadir peque...     1     -1
# 45           0  * dilma despedir politico * \n \n prezar brasi...     1     -1
# 46           0  * ex presidente dilma despedir politico * rost...     1     -1
# ...        ...                                                ...   ...    ...
# 1489         0  frase marcante hirstorira \n \n sortirr lancar...     1     -1
# 1490         0  frase marcante hirstorira \n \n sortirr lancar...     1     -1
# 1534         0  atencao \n postar policia rodoviario federal v...     0      1
# 1543         0  ladrao tentar roubar faca dentro trem saber na...     1     -1
# 1545         0  * _ ir comecar campanha brasileiro querer bem ...     1     -1
#
# [101 rows x 6 columns]

# %%
print('percentage of error in expanded data', n_errors_expanded/len(df_test[df_test['error']!=0]))
# Out:
# percentage of error in expanded data 0.36727272727272725

# %%
test_original = df_test[df_test['original']==1]
y_test = test_original['misinformation']
X_test = bow.transform(test_original['preprocessed_text'])

y_prob = clf.predict_proba(X_test)[:,1]
y_prob_train = clf.predict_proba(X_train)[:,1]
# threshold moving

thr = utils.optimal_threshold(y_prob_train, y_train)
print(thr)
y_pred = [1 if p >= thr else 0 for p in y_prob]
utils.get_test_metrics(y_test, y_pred, y_prob, full_metrics = True)
# Out:
# 0.38
#               precision    recall  f1-score   support
#
#            0       0.81      0.83      0.82       484
#            1       0.75      0.72      0.74       340
#
#     accuracy                           0.79       824
#    macro avg       0.78      0.78      0.78       824
# weighted avg       0.79      0.79      0.79       824
#
# AUC:  0.8534394749635391
# (0.7888349514563107,
#  0.754601226993865,
#  0.8228105906313645,
#  0.7235294117647059,
#  0.8228105906313645,
#  0.7387387387387387,
#  0.8228105906313645,
#  0.8534394749635391)

# %%
list(df_test[df_test['original']==0]['text'])[0:5]
# Out:
# ['Bolsonaro e Mourão  estão numa pizzaria jantando.\nUm cliente aproxima-se deles e pergunta:\n- Sobre o que estão conversando de forma tão animada?\n- Estamos fazendo planos para resolver o problema do Brasil de forma rápida e super discreta....responde Bolsonaro...\n- Uau!, exclama o cliente...\nE quais são esses planos?\n- No Brasil, vamos matar 14 milhões de petistas, um Gremista e um Colorado, responde Mourão.\nO convidado parece confuso e pergunta:\n- Um... Gremista e um Colorado ?\nPor que é que vão matar um Gremista e um Colorado ?\nBolsonaro dá uma palmada nas costas do Mourão e exclama:\n- Não te disse?\nNinguém vai perguntar pelos 14 milhões de petistas!',
#  '😉😉😉😉😽😹\nBolsonaro e Mourão estão numa pizzaria jantando.\nUm cliente aproxima-se deles e pergunta:\n- Sobre o que estão conversando de forma tão animada?\n- Estamos fazendo planos para resolver o problema do Brasil de forma rápida e super discreta....responde Bolsonaro...\n- Uau!, exclama o cliente...\nE quais são esses planos?\n- No Brasil, vamos matar 14 milhões de petistas, um Gremista e um Colorado, responde Mourão.\nO convidado parece confuso e pergunta:\n- Um... Gremista e um Colorado ?\nPor que é que vão matar um Gremista e um Colorado ?\nBolsonaro dá uma palmada nas costas do Mourão e exclama:\n- Não te disse?\nNinguém vai perguntar pelos 14 milhões de petistas!!',
#  'Bolsonaro e Mourão  estão numa pizzaria jantando.\nUm cliente aproxima-se deles e pergunta:\n- Sobre o que estão conversando de forma tão animada?\n- Estamos fazendo planos para resolver o problema do Brasil de forma rápida e super discreta....responde Bolsonaro...\n- Uau!, exclama o cliente...\nE quais são esses planos?\n- No Brasil, vamos matar 14 milhões de petistas, um gremista e um colorado, responde Mourão.\nO convidado parece confuso e pergunta:\n- Hummm... um gremista e um colorado?\nPor que é que vão matar um gremista e um colorado?\nBolsonaro dá uma palmada nas costas do Mourão e exclama:\n- Não te disse?\nNinguém vai perguntar pelos 14 milhões de petistas!\n🙄🙄',
#  'Bolsonaro e Mourão  estão numa churrascaria jantando.\nUm cliente aproxima-se deles e pergunta:\n- Sobre o que estão conversando de forma tão animada?\n- Estamos fazendo planos para resolver o problema do Brasil de forma rápida e super discreta....responde Bolsonaro...\n- Uau!, exclama o cliente...\nE quais são esses planos?\n- No Brasil, vamos matar 14 milhões de petistas, um colorado e um gremista, responde Mourão.\nO convidado parece confuso e pergunta:\n- Um... Colorado e um gremista?\nPor que é que vão matar um colorado e um gremista?\nBolsonaro dá um tapa nas costas do Mourão e exclama:\n- Não te disse?\nNinguém vai perguntar pelos 14 milhões de petistas!',
#  'https://youtu.be/QvSF3FrYs6g\n\nFalta 35 dias para a eleição.\n\nNo Tocantins ao senado temos na chapa de Bolsonaro o agente da polícia federal: Farlei\n\nFarlei tem recebido apoio dos apoiadores de Bolsonaro dos grupos:\n\n1. Amor pelo Brasil - Cecília Santana\n2. Direita Palmas - Josimar Ribeiro\n3. Organiza Palmas - Flávio Mota\n4. Bolsonaro Nova Olinda - Eliz\n5. Endireita Colinas - Teixeira\n6. Bolsonaro Miracema - Osmir\n7. Ficha limpa já-\nWaldez\n8. Endireira Paraiso - Fernandez\n9.\n10.\n11.\n12.\n17.\n14.\n15.\n\n\nDeixe registrado aqui o seu apoio. Participe e coloque o grupo WhatsApp que você administra e seu nome. Obrigado!\n\nChegou a nossa vez! *Junto com o povo* (slogan siquerista do inferno) o escambáu! 👊\n\n👉 Juntos com Deus, com o Brasil e com Jair Bolsonaro 😎\n\n*Brasil acima de tudo, Deus acima de todos*']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
