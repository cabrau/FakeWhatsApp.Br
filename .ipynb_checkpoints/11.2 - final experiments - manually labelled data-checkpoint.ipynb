# %% [markdown]
# # Exploiting all the methods tried so far

# %%
#utils
import emoji, re, string, time, os
from utils import get_test_metrics
from utils import preprocess
from utils import get_user_features, get_top_users
import pandas as pd
import numpy as np
from scipy.stats import randint
import pickle
import math

#nlp
import nltk
from nltk.corpus import stopwords
import spacy
from gensim.models import Word2Vec
from gensim.models.callbacks import CallbackAny2Vec

#dataviz
import matplotlib.pyplot as plt
import seaborn as sns

#features
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import linear_kernel
from sklearn import metrics
from sklearn.model_selection import train_test_split

#models
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import ComplementNB
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform

#data balancing
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import RandomOverSampler

# %matplotlib inline
sns.set(style="darkgrid")

# %%
def optimal_threshold(prob,y):
    best_thresold = 0
    best_score = 0
    
    for i in range(100):
        threshold = i/100
        y_pred = [1 if p >= threshold else 0 for p in prob]
        score = metrics.accuracy_score(y,y_pred)
        
        if score > best_score:
            #print(score)
            best_thresold = threshold
            best_score = score
            
    return best_thresold

# optimal mlp for tfidf
def get_mlp():
    clf = MLPClassifier(activation = 'relu', solver = 'adam',random_state = 42, 
                   tol = 1e-3, verbose = False, early_stopping = True, 
                   n_iter_no_change = 10, max_iter = 200,
                   hidden_layer_sizes = (100,), alpha = 0.0067, 
                   learning_rate_init = .00026, batch_size = 50)
    return clf

# tunning hyperparameters mlp
n_iter = 10
def random_layers():
    '''
    Create a tuple random of hidden_layer_sizes. 
    '''
    n_layers = np.random.randint(1,4)
    layers_list = []
    for i in range(n_layers):            
        hidden_neurons = np.random.randint(1,15)*25
        layers_list.append(hidden_neurons)
    layers_tuple = tuple(layers_list)
    return layers_tuple

def random_search_mlp(X_train,y_train,n_iter=10):
    
    # hyperparams to optimize
    hidden_layers = []
    alphas = []
    batch_sizes = []
    learning_rate_inits = []
    # sample
    np.random.seed(0)
    for i in range(n_iter):   
        hl = random_layers()
        #print(hl,end = '; ')
        hidden_layers.append(hl)
        ap = 10**np.random.uniform(-6,-2)
        #print(ap, end = '; ')
        alphas.append(ap)
        learning = 10**np.random.uniform(-4,-1)
        #print(learning, end = '; ')
        learning_rate_inits.append(learning)
        batch = np.random.randint(1,7)*50 #math.floor(10**np.random.uniform(1.5,2.6)) #np.random.randint(2,30)*10
        #print(batch)
        batch_sizes.append(batch)

    # tunning
    X_train_v, X_val, y_train_v, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=42)
    best_score = 0
    i = 0
    for hl,bs,al,lri in zip(hidden_layers,batch_sizes,alphas,learning_rate_inits):
        
        clf = optimized_mlp(hl,bs,al,lri)

        print(i, end= ' ')
        i+=1
        print()
        print('hidden layers: {a}; alpha: {b:.5f}; learning rate: {c:.5f}; batch: {d}'.format(a=hl,b=al,c=lri,d=bs))    
        clf.fit(X_train_v, y_train_v)
        y_pred = clf.predict(X_val)        
        y_prob = clf.predict_proba(X_val)[:,1]
        
        fpr, tpr, thresholds = metrics.roc_curve(y_val, y_prob, pos_label=1)
        roc_auc = metrics.auc(fpr, tpr)
        print('AUC: {a:.3f}'.format(a=roc_auc))       
        if roc_auc > best_score:
            best_score = roc_auc
            best_params = (hl,bs,al,lri)

        #print('validation rmse: {a:.3f}'.format(a=rmse))


    hl,bs,al,lri = best_params
    print()
    print('--------------------')
    print('BEST PARAMETERS (validation AUC = {a:.3f})'.format(a=best_score))
    print('hidden layers: {a}; alpha: {b:.5f}; learning rate: {c:.5f}; batch: {d}'.format(a=hl,b=al,c=lri,d=bs))
    print('--------------------')
    return hl,bs,al,lri

def optimized_mlp(hl,bs,al,lri):
    clf = MLPClassifier(activation = 'relu', solver = 'adam',random_state = 42, 
                   tol = 1e-4, verbose = False, early_stopping = True, 
                   n_iter_no_change = 10, max_iter = 100,
                   hidden_layer_sizes = hl, alpha = al, 
                   learning_rate_init = lri, batch_size = bs)
    return clf

def train_test(clf,X_train,X_test,y_train,y_test):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    y_prob = clf.predict_proba(X_test)[:,1]
    test_metrics = get_test_metrics(y_test, y_pred, y_prob, full_metrics = True)
    return test_metrics

# %% [markdown]
# # Load data

# %%
# messages
df = pd.read_csv('data/2018/fakeWhatsApp.BR_2018.csv')
df_texts = pd.read_csv('data/2018/high_quality_labels/fakeWhatsApp.BR_2018_preprocessed_texts.csv')
df = pd.concat([df, df_texts], axis=1)
df.drop(columns=['Unnamed: 0'],inplace=True)
corpus = list(df[df['midia']==0]['preprocessed_text_lemma'].unique())

# sorting by time
def custom_time(data,hora):
    string = data + " " + hora
    return string

df['timestamp'] = df.apply(lambda x: custom_time(x['date'],x['hour']),axis=1)
df['timestamp'] = pd.to_datetime(df['timestamp'], format='%d/%m/%y %H:%M')
df.sort_values(by='timestamp',inplace=True)

#removing duplicates and selecting only labelled data
df = df.drop_duplicates(subset=['text'])
df = df[df['midia']==0]
#df['viral'] = [1 if mis==1 else vir for mis,vir in zip(df['misinformation'],df['viral'])]
#df = df[df['viral']==1]

df.reset_index(drop=True,inplace=True)

df.tail(3)

# %%
print('manually labelled messages:',len(df[df['shares']>1]))

# %% [markdown]
# ## Expansion of dataset

# %%
# Automatic expansion of dataset by cosine similarity

from sklearn.metrics.pairwise import cosine_similarity

vectorizer = TfidfVectorizer(max_features = None, ngram_range = (1,1), #(1,3) 
                             lowercase = False, token_pattern = r'[^\s]+',binary=True)

texts = df['text']
labelled_texts = list(df[df['shares']>1]['text'])
labels = df[df['shares']>1]['misinformation']

non_labelled = vectorizer.fit_transform(texts)  
labelled_tfidf = vectorizer.transform(labelled_texts)

distances = cosine_similarity(non_labelled, labelled_tfidf)

# #max similaritie for each document
max_sim = distances.max(axis = 1)
max_arg = distances.argmax(axis = 1)

# %%
#pd.set_option('display.max_colwidth', None)
mask = (max_sim < 1) & (max_sim >= 0.9)
non_labelled_texts = texts[mask].reset_index(drop=True)
idx = max_arg[mask]
best_match = np.array(labelled_texts)[idx]
assigned_labels = labels[idx].reset_index(drop=True)

# %%
non_labelled_texts = list(non_labelled_texts)
new_labels = []
new_virals = []

for text,mis,vir in zip(df['text'],df['misinformation'],df['viral']):
    
    if text in non_labelled_texts:
        i = non_labelled_texts.index(text)
        label = assigned_labels[i]
        new_labels.append(label)
        new_virals.append(1)
    else:
        new_labels.append(mis)
        new_virals.append(vir)

# %%
# select data

#texts
original_texts = df['text']
texts = df['preprocessed_text_lemma']
#target
y = df['misinformation']

# cut index
cut = math.floor(len(df)*0.8)
cut
# Out:
# 4227

# %%
def print_class_balance(y):
    pos_mask = y == 1 
    pos = y[pos_mask]
    neg_mask = y == 0 
    neg = y[neg_mask]
    values = [pos.shape[0],neg.shape[0]]
    keys = ['misinformation', 'non-misinformation']
    g = sns.barplot(x = keys, y = values)
    for p in g.patches:
        g.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., 
                                                   p.get_height()), ha = 'center', 
                   va = 'center', xytext = (0, 5), textcoords = 'offset points')
print('data balance in dataset')        
print_class_balance(y)
# Out:
# data balance in dataset

# %% [markdown]
# # Train-test split

# %%
# use only characters
# texts = df['text']
# texts = [' '.join(list(t)) for t in texts]

# train with the 80% older messages; test with the 20% newer
# split by time

X_train_texts = texts[0:cut]
y_train= y[0:cut]
X_test_texts = texts[cut:]
y_test = y[cut:]

X_train_og_texts = original_texts[0:cut]
X_test_og_texts = original_texts[cut:]

corpus = [t.split() for t in corpus if t not in X_test_texts and type(t)==str]

print('train')
print_class_balance(y_train)
plt.figure()
print('test')
print_class_balance(y_test)
# Out:
# train
# test

# %%
len(corpus)
# Out:
# 99016

# %%
print('samples train')
pos_mask = y_train == 1 
mis = X_train_og_texts[pos_mask]
neg_mask = y_train == 0 
non_mis = X_train_og_texts[neg_mask]
sample = list(mis.sample(1))
print()
print('misinformation')
for m in sample:
    print('*********')
    print(m)
    print()
    
sample = list(non_mis.sample(1))
print('---------------------------------------')
print('non misinformation')
for m in sample:
    print('*********')
    print(m)
    print()
# Out:
# samples train
#
# misinformation
# *********
# Boa tarde.
# Pessoal estava vendo que os Venezuelanos estão invadindo casas
# Comércio
# E destruindo Propiedade
# Em município em Roraima.
# Os prefeitos a FORÇA NACIONAL
# Estão retirando eles. Estão reivindicando DIREITOS e casas pra morar e trabalho. Culpa do PT PPS PSB
# PSDB PMDB PCDOB PSOL RED
# Esses partidos vivem do caos da desgraça da pobreza da violência.
#
# ---------------------------------------
# non misinformation
# *********
# Boa tarde a todos, quarta feira teremos uma ação nacional, todos Patriotas, Intervencionistas e cidadão de bem devem participar em um ato de apoio a saúde do nosso Capitão Bolsonaro e principalmente pela garantia da democracia de nosso país, precisamos mostrar a eles que não somos intolerantes e sim conscientes, parabéns Maggie pela iniciativa.
#
# *Cabo Marcio Patriota convoca.*
#
# Quarta-feira
# 12/09/2018
# HEMOBA Salvador e Pontos de doação de sangue em todo país.

# %%
print('samples test')
pos_mask = y_test == 1 
mis = X_test_og_texts[pos_mask]
neg_mask = y_test == 0 
non_mis = X_test_og_texts[neg_mask]
sample = list(mis.sample(1))
print()
print('misinformation')
for m in sample:
    print('*********')
    print(m)
    print()
    
sample = list(non_mis.sample(1))
print('---------------------------------------')
print('non misinformation')
for m in sample:
    print('*********')
    print(m)
    print()
# Out:
# samples test
#
# misinformation
# *********
# Alguem  tirou fotos do boletim de urna? Podem enviar para mim? Grato
#
# ---------------------------------------
# non misinformation
# *********
# O bambu tá gemendo. Quem disse que tava tendo virada do PT, principalmente em São Paulo. Kkkkkkkkk. O PT é o próprio Fakenews.

# %% [markdown]
# # BoW

# %%
#vectorizer = TfidfVectorizer(max_features = None, ngram_range = (2,2), lowercase = True, token_pattern = r'[^\s]+')
vectorizer = CountVectorizer(max_features = None, ngram_range = (1,3), #(1,3) 
                             lowercase = False, token_pattern = r'[^\s]+',binary=True)
vectorizer.fit(X_train_texts)   
X_train = vectorizer.transform(X_train_texts)
X_test = vectorizer.transform(X_test_texts)
X_train.shape
# Out:
# (4227, 297010)

# %%
print(vectorizer.get_feature_names()[100:150])
# Out:
# ['! ! feliz', '! ! fernando', '! ! ficar', '! ! filhar', '! ! fiscal', '! ! focar', '! ! foraaaaaa', '! ! forcar', '! ! fraudar', '! ! futurar', '! ! ganhar', '! ! general', '! ! gente', '! ! gloriar', '! ! gracas', '! ! grande', '! ! grupar', '! ! haddad', '! ! hoje', '! ! homem', '! ! homenagem', '! ! incluir', '! ! incrivel', '! ! investir', '! ! ir', '! ! ja', '! ! jipeiros', '! ! jogar', '! ! jovem', '! ! kkk', '! ! l', '! ! ler', '! ! luis', '! ! lula', '! ! lutarr', '! ! m', '! ! mal', '! ! mandar', '! ! manter', '! ! maravilhoso', '! ! marino', '! ! melhorar', '! ! membro', '! ! mentir', '! ! midias', '! ! mil', '! ! missao', '! ! mito', '! ! moior', '! ! morar']

# %%
print('logistic regression + binary bow')
clf = LogisticRegression()
clf.fit(X_train,y_train)

y_prob = clf.predict_proba(X_test)[:,1]
y_prob_train = clf.predict_proba(X_train)[:,1]
# threshold moving

#thr = optimal_threshold(y_prob,y_test)
thr = optimal_threshold(y_prob_train,y_train)
print(thr)
y_pred = [1 if p >= thr else 0 for p in y_prob]
get_test_metrics(y_test, y_pred, y_prob, full_metrics = True)
# Out:
# logistic regression + binary bow
# 0.39
#               precision    recall  f1-score   support
#
#            0       0.72      0.81      0.76       579
#            1       0.73      0.62      0.67       478
#
#     accuracy                           0.72      1057
#    macro avg       0.73      0.72      0.72      1057
# weighted avg       0.73      0.72      0.72      1057
#
# AUC:  0.805999378527399
# (0.7246925260170294,
#  0.7286063569682152,
#  0.762836185819071,
#  0.6234309623430963,
#  0.762836185819071,
#  0.6719278466741827,
#  0.762836185819071,
#  0.805999378527399)

# %%
print('mlp + bow')
clf = MLPClassifier(activation = 'relu', solver = 'adam',random_state = 42, 
                   tol = 1e-3, verbose = True, early_stopping = True, 
                   n_iter_no_change = 3, max_iter = 20,
                   hidden_layer_sizes = (100,), alpha = .0001, 
                   learning_rate_init = .0001, batch_size = 200)

clf.fit(X_train,y_train)

y_prob = clf.predict_proba(X_test)[:,1]
y_prob_train = clf.predict_proba(X_train)[:,1]
# threshold moving
thr = optimal_threshold(y_prob_train,y_train)
print(thr)
y_pred = [1 if p >= thr else 0 for p in y_prob]
get_test_metrics(y_test, y_pred, y_prob, full_metrics = True)
# Out:
# mlp + bow
# Iteration 1, loss = 0.68959993
# Validation score: 0.489362
# Iteration 2, loss = 0.56691106
# Validation score: 0.567376
# /home/cabral/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:587: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# 0.54
#               precision    recall  f1-score   support
#
#            0       0.69      0.72      0.70       579
#            1       0.64      0.60      0.62       478
#
#     accuracy                           0.67      1057
#    macro avg       0.66      0.66      0.66      1057
# weighted avg       0.66      0.67      0.66      1057
#
# AUC:  0.7305265896329698
# (0.6650898770104068,
#  0.6377777777777778,
#  0.7015177065767285,
#  0.600418410041841,
#  0.7015177065767285,
#  0.6185344827586207,
#  0.7015177065767285,
#  0.7305265896329698)

# %% [markdown]
# # Topic modelling (LDA)

# %%
# topics
from gensim.models import LdaModel
from gensim.corpora.dictionary import Dictionary
n_topics = 15

def train_lda(corpus, n_topics = 100):
    common_texts = [x.split() for x in corpus]
    common_dictionary = Dictionary(common_texts)
    common_corpus = [common_dictionary.doc2bow(text) for text in common_texts]
    lda = LdaModel(common_corpus, num_topics=n_topics)
    return lda, common_dictionary

lda, common_dictionary = train_lda(X_train_texts, n_topics)

# %%
# vectorizing
def tup2array(tuples,n_topics):
    topics = np.zeros(n_topics)
    for t, p in tuples:
        topics[t] = p
    return topics

def vectorize_topics(X,lda):
    X = [lda[x] for x in X]
    X = [tup2array(v,lda.num_topics) for v in X]
    return X

def texts2topics(texts,lda):
    X = [x.split() for x in texts]
    X = [common_dictionary.doc2bow(text) for text in X]
    X = vectorize_topics(X,lda)
    return X
    

X_train_topics = texts2topics(X_train_texts,lda)
X_test_topics = texts2topics(X_test_texts,lda)

# %%
print('logistic regression + lda')
clf = LogisticRegression()
clf.fit(X_train_topics,y_train)
y_prob = clf.predict_proba(X_test_topics)[:,1]
y_prob_train = clf.predict_proba(X_train_topics)[:,1]
thr = optimal_threshold(y_prob_train,y_train)
print(thr)
y_pred = [1 if p >= thr else 0 for p in y_prob]
test_metrics = get_test_metrics(y_test, y_pred, y_prob, full_metrics = True)
# Out:
# logistic regression + lda
# 0.52
#               precision    recall  f1-score   support
#
#            0       0.51      0.52      0.51       547
#            1       0.63      0.62      0.63       731
#
#     accuracy                           0.58      1278
#    macro avg       0.57      0.57      0.57      1278
# weighted avg       0.58      0.58      0.58      1278
#
# AUC:  0.5978012139339814

# %%
print('mlp + lda')
# clf = MLPClassifier(activation = 'relu', solver = 'adam',random_state = 42, 
#                    tol = 1e-3, verbose = True, early_stopping = True, 
#                    n_iter_no_change = 3, max_iter = 100,
#                    hidden_layer_sizes = (100,), alpha = .00001, 
#                    learning_rate_init = .0001, batch_size = 32)
# hl,bs,al,lri = random_search_mlp(X_train_topics,y_train,n_iter)
# clf = optimized_mlp(hl,bs,al,lri)

# results = train_test(clf,X_train_topics,X_test_topics,y_train,y_test)

hl,bs,al,lri = random_search_mlp(X_train_topics,y_train,n_iter)
clf = optimized_mlp(hl,bs,al,lri)
clf.fit(X_train_topics,y_train)
y_prob = clf.predict_proba(X_test_topics)[:,1]
y_prob_train = clf.predict_proba(X_train_topics)[:,1]
thr = optimal_threshold(y_prob_train,y_train)
print(thr)
y_pred = [1 if p >= thr else 0 for p in y_prob]
test_metrics = get_test_metrics(y_test, y_pred, y_prob, full_metrics = True)
# Out:
# mlp + lda
# 0
# hidden layers: (150,); alpha: 0.00238; learning rate: 0.03748; batch: 100
# AUC: 0.669
# 1
# hidden layers: (75, 125); alpha: 0.00002; learning rate: 0.00015; batch: 250
# AUC: 0.621
# 2
# hidden layers: (50, 175, 200); alpha: 0.00013; learning rate: 0.00506; batch: 300
# AUC: 0.691
# 3
# hidden layers: (350, 225); alpha: 0.00000; learning rate: 0.00011; batch: 200
# AUC: 0.638
# 4
# hidden layers: (25, 75); alpha: 0.00008; learning rate: 0.02528; batch: 300
# AUC: 0.654
# 5
# hidden layers: (200, 25, 50); alpha: 0.00000; learning rate: 0.06823; batch: 150
# AUC: 0.651
# 6
# hidden layers: (200,); alpha: 0.00001; learning rate: 0.02102; batch: 250
# AUC: 0.681
# 7
# hidden layers: (25, 25, 125); alpha: 0.00030; learning rate: 0.00686; batch: 250
# AUC: 0.664
# 8
# hidden layers: (125, 250); alpha: 0.00006; learning rate: 0.00691; batch: 100
# AUC: 0.678
# 9
# hidden layers: (200, 250); alpha: 0.00757; learning rate: 0.00911; batch: 200
# AUC: 0.685
#
# --------------------
# BEST PARAMETERS (validation AUC = 0.691)
# hidden layers: (50, 175, 200); alpha: 0.00013; learning rate: 0.00506; batch: 300
# --------------------
# 0.47
#               precision    recall  f1-score   support
#
#            0       0.55      0.64      0.59       547
#            1       0.69      0.60      0.64       731
#
#     accuracy                           0.62      1278
#    macro avg       0.62      0.62      0.62      1278
# weighted avg       0.63      0.62      0.62      1278
#
# AUC:  0.6649277116569173

# %% [markdown]
# # Contextual features
# * How many times the message was shared
# * How many people have seen it
# * How many groups
# * Features from users that shared the message / credibility
# * Spreading velocity

# %% [markdown]
# # Combine with other viral messages sent by users
# **Ideias**
# * get the last texts from the user who sent the message
# * get all viral texts sent by all users
# * use unique texts or count the repeated?
# * weight the words from principal message
# * count number of times that each user posted the messages

# %%
df
# Out:
#                        id      date   hour ddi country country_iso3 ddd  \
# 0     6942577183305588053  02/07/18  10:46  55  BRASIL          BRA  91
# 1    -2072140886659020977  02/07/18  10:50  55  BRASIL          BRA  67
# 2    -5100443702615645928  02/07/18  11:03  55  BRASIL          BRA  21
# 3    -1561843698204261697  02/07/18  16:31  55  BRASIL          BRA  63
# 4    -5876784761398352499  02/07/18  18:09  55  BRASIL          BRA  61
# ...                   ...       ...    ...  ..     ...          ...  ..
# 6382  6237256410123034833  28/10/18  21:05  55  BRASIL          BRA  73
# 6383  2485357201479715834  28/10/18  21:53  55  BRASIL          BRA  62
# 6384   657760642306071754  28/10/18  22:19  55  BRASIL          BRA  63
# 6385  3795679520023557695  28/10/18  22:25  55  BRASIL          BRA  62
# 6386 -2345811543631484060  28/10/18  23:03   ?       ?            ?   ?
#
#                    state    group  midia  ...  characters  words  viral  \
# 0                   Pará  2018_10      0  ...        4099    634      1
# 1     Mato Grosso do Sul  2018_14      0  ...         247     40      1
# 2         Rio de Janeiro  2018_59      0  ...        1192    164      1
# 3              Tocantins  2018_56      0  ...         177     31      1
# 4       Distrito Federal  2018_20      0  ...         122     17      1
# ...                  ...      ...    ...  ...         ...    ...    ...
# 6382               Bahia  2018_44      0  ...          71      9      1
# 6383               Goiás  2018_56      0  ...        1250    161      1
# 6384           Tocantins   2018_8      0  ...          68     12      1
# 6385               Goiás  2018_44      0  ...          49      8      1
# 6386                   ?   2018_4      0  ...          50      9      1
#
#       shares                                               text  \
# 0          1  O dia em que ex-guerrilheiro, militantes e des...
# 1          3  O nível dos jornalistas do programa Roda Viva ...
# 2          2  *Atenção*\n\nPrecisamos da ajuda de todos você...
# 3          5  Gestão do colombiano na capital, imagina ele n...
# 4          2  🛑🛑🛑🛑🛑🛑\nInterrompendo momentaneamente a conver...
# ...      ...                                                ...
# 6382       1  🇧🇷🇧🇷🇧🇷🇧🇷🇧🇷🇧🇷🇧🇷🇧🇷BBBBBBAAAASSSSSLLLL #B17 17 #B...
# 6383       1  OLHA O QUANTO AVANÇAMOS! SE LIGA NESSA LIMPEZA...
# 6384       2  Alguem  tirou fotos do boletim de urna? Podem ...
# 6385       2  Em frente a polícia federal... Dormitório do Lula
# 6386       2  Se alguém aí quiser sair pra facilitar eu agra...
#
#      misinformation                                  preprocessed_text  \
# 0                 1  dia ex - guerrilheiro , militantes desarmament...
# 1                 1  nivel jornalistas programa roda viva tao baixo...
# 2                 0  * atencao * \n \n precisamos ajuda todos voces...
# 3                 1  gestao colombiano capital , imagina governo , ...
# 4                 1  🛑 🛑 🛑 🛑 🛑 🛑 \n interrompendo momentaneamente c...
# ...             ...                                                ...
# 6382              1  🇧 🇷 🇧 🇷 🇧 🇷 🇧 🇷 🇧 🇷 🇧 🇷 🇧 🇷 🇧 🇷 bbbbbbaaaassss...
# 6383              1  olha quanto avancamos ! liga nessa limpeza ! e...
# 6384              1  alguem tirou fotos boletim urna ? podem enviar...
# 6385              0       frente policia federal . . . dormitorio lula
# 6386              0       alguem ai quiser sair pra facilitar agradeco
#
#                               preprocessed_text_stemmed  \
# 0     dia ex - guerrilh , milit desarmament tent "fu...
# 1     nivel jornal program rod viv tao baix ate marc...
# 2     * atenca * \n \n precis ajud tod voc * mant av...
# 3     gesta colombi capit , imagin govern , grac deu...
# 4     🛑 🛑 🛑 🛑 🛑 🛑 \n interromp momentane convers , n...
# ...                                                 ...
# 6382  🇧 🇷 🇧 🇷 🇧 🇷 🇧 🇷 🇧 🇷 🇧 🇷 🇧 🇷 🇧 🇷 bbbbbbaaaassss...
# 6383  olh quant avanc ! lig ness limp ! esta : \n \n...
# 6384     algu tir fot boletim urn ? pod envi mim ? grat
# 6385              frent polic feder . . . dormitori lul
# 6386                algu ai quis sair pra facil agradec
#
#                                 preprocessed_text_lemma           timestamp
# 0     dia ex - guerrilheiro , militante desarmamenti... 2018-07-02 10:46:00
# 1     nivel jornalista programarr rodar vivo tao bai... 2018-07-02 10:50:00
# 2     * atencao * \n \n precisar ajudar todo voces *... 2018-07-02 11:03:00
# 3     gestao colombiano capital , imaginar governar ... 2018-07-02 16:31:00
# 4     🛑 🛑 🛑 🛑 🛑 🛑 \n interromper momentaneamente con... 2018-07-02 18:09:00
# ...                                                 ...                 ...
# 6382  🇧 🇷 🇧 🇷 🇧 🇷 🇧 🇷 🇧 🇷 🇧 🇷 🇧 🇷 🇧 🇷 bbbbbbaaaassss... 2018-10-28 21:05:00
# 6383  olhar quantum avancamos ! ligar nessa limpeza ... 2018-10-28 21:53:00
# 6384  alguem tirar foto boletim urna ? poder enviar ... 2018-10-28 22:19:00
# 6385      frente policiar federal . . . dormitorio lula 2018-10-28 22:25:00
# 6386       alguem ai querer sair pra facilitar agradeco 2018-10-28 23:03:00
#
# [6387 rows x 21 columns]

# %%
def combine_texts(list_texts,X_train_texts,constant=5):
    
    combined_texts_train = []
    
    for text in list_texts:
        
        if len(text.split()) >= 50:
            combined_texts_train.append(text)
            continue
            
        users = df[df['preprocessed_text_lemma']==text]['id'].unique()
        viral_texts = []
        for user in users:
            viral_texts_user = df[df['id']==user]['preprocessed_text_lemma'].unique() #use only unique texts
            viral_texts_user = list(viral_texts_user)
            # use only texts in train set
            viral_texts_user = [t for t in viral_texts_user if t in X_train_texts]
            if viral_texts_user:
                viral_texts.append(viral_texts_user)

        # discard repeated texts
        if not viral_texts:
            viral_texts = ''

        viral_texts = set(viral_texts)
        viral_texts.discard(text)

        # weight message        
        weighted = [text]*(constant) # or use constant: 5 *len(users)+

        # join texts
        combined = weighted + list(viral_texts)
        combined = ' '.join(combined)
        combined_texts_train.append(combined)
    return combined_texts_train

# %%
combined_texts_train = combine_texts(X_train_texts,X_train_texts,20)
combined_texts_test = combine_texts(X_test_texts,X_train_texts,20)

# %%
# vectorizer = TfidfVectorizer(max_features = None, ngram_range = (2,2), 
#                              lowercase = True, token_pattern = r'[^\s]+')
vectorizer = CountVectorizer(max_features = None, ngram_range = (1,3), #(1,3) 
                             lowercase = False, token_pattern = r'[^\s]+')
vectorizer.fit(combined_texts_train)   
X_train = vectorizer.transform(combined_texts_train)
X_test = vectorizer.transform(combined_texts_test)
X_train.shape
# Out:
# (5109, 322938)

# %%
print('logistic regression + w2v')
clf = LogisticRegression()
clf.fit(X_train,y_train)
y_prob = clf.predict_proba(X_test)[:,1]

# threshold moving
y_prob_train = clf.predict_proba(X_train)[:,1]
thr = optimal_threshold(y_prob_train,y_train)   
print(thr)
y_pred = [1 if p >= thr else 0 for p in y_prob]
get_test_metrics(y_test, y_pred, y_prob, full_metrics = True)
# Out:
# logistic regression + tf-idf
# /home/cabral/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
# Out:
# 0.23
#               precision    recall  f1-score   support
#
#            0       0.71      0.59      0.64       547
#            1       0.73      0.82      0.77       731
#
#     accuracy                           0.72      1278
#    macro avg       0.72      0.70      0.71      1278
# weighted avg       0.72      0.72      0.71      1278
#
# AUC:  0.761342179829289
# (0.7190923317683882,
#  0.7262773722627737,
#  0.642073778664008,
#  0.8166894664842681,
#  0.642073778664008,
#  0.7688345138441725,
#  0.642073778664008,
#  0.761342179829289)

# %%
clf = MLPClassifier(activation = 'relu', solver = 'adam',random_state = 42, 
                   tol = 1e-3, verbose = True, early_stopping = True, 
                   n_iter_no_change = 3, max_iter = 7,
                   hidden_layer_sizes = (100,), alpha = .00001, 
                   learning_rate_init = .0001, batch_size = 32)
results = train_test(clf,X_train,X_test,y_train,y_test)
# Out:
# Iteration 1, loss = 0.68473253
# Validation score: 0.534247
# Iteration 2, loss = 0.63156504
# Validation score: 0.671233
# Iteration 3, loss = 0.56036169
# Validation score: 0.804305
# Iteration 4, loss = 0.49052290
# Validation score: 0.804305
# Iteration 5, loss = 0.42751253
# Validation score: 0.812133
# Iteration 6, loss = 0.37192068
# Validation score: 0.810176
# Iteration 7, loss = 0.32365356
# Validation score: 0.812133
#               precision    recall  f1-score   support
#
#            0       0.64      0.70      0.67       547
#            1       0.76      0.70      0.73       731
#
#     accuracy                           0.70      1278
#    macro avg       0.70      0.70      0.70      1278
# weighted avg       0.71      0.70      0.70      1278
#
# AUC:  0.7955444071255473
# /home/cabral/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:585: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (7) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %% [markdown]
# # Word embeddings

# %%
from gensim.models import Word2Vec
from gensim.models.callbacks import CallbackAny2Vec

# %%
len(corpus)
# Out:
# 99016

# %%
class EpochLogger(CallbackAny2Vec):
    """Callback to log information about training"""

    def __init__(self):
        self.epoch = 0

    def on_epoch_begin(self, model):
        self.epoch += 1
        print("W2V: Epoch #{}".format(self.epoch))
        
epoch_logger = EpochLogger()

# w2v = Word2Vec(min_count=1)
# w2v.build_vocab(corpus)  # prepare the model vocabulary
# w2v.train(corpus, total_examples=model.corpus_count, 
#             epochs=10, compute_loss=True, 
#             callbacks=[epoch_logger])

# #w2v = Word2Vec(sentences=corpus, window=5, min_count=1, workers=4, epochs = 10) #callbacks=[epoch_logger]
# w2v.save("data/2018/word2vec_train.model")

w2v = Word2Vec.load("data/2018/word2vec_train.model")
# Out:
# W2V: Epoch #1
# W2V: Epoch #2
# W2V: Epoch #3
# W2V: Epoch #4
# W2V: Epoch #5
# W2V: Epoch #6
# W2V: Epoch #7
# W2V: Epoch #8
# W2V: Epoch #9
# W2V: Epoch #10

# %%
w2v.most_similar(positive=['deus'])
# Out:
# /home/cabral/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('dars', 0.732843279838562),
#  ('senhor', 0.6729269027709961),
#  ('paz', 0.6649038791656494),
#  ('oracao', 0.6637418866157532),
#  ('vosso', 0.6563032865524292),
#  ('orar', 0.6376925110816956),
#  ('coracao', 0.6290973424911499),
#  ('ti', 0.6263786554336548),
#  ('sabedoria', 0.6253186464309692),
#  ('ceus', 0.6174683570861816)]

# %%
def vectorize_text(model, text, method='mean'):
        """
        Convert all words in a text to their embedding vector
        and calculate a vector for the text, by the mean or the sum of word vectors
        Parameters
        ----------
        text: str
        Text from wich the word vector's will be calculated    
        
        method: str
        'mean' or 'sum'
            
        Returns
        -------
        vec: numpy.ndarray 
        Array of the word embeddings from the given text 
        """
        n = model.vector_size
        X = np.empty(shape=[0, n])
        words = text.split()
        for word in words:
            try:
                vec = model[word]
                X = np.append(X,[vec], axis = 0)
            # if oov:    
            except:
                #print('word not in vocabulary: ', word)
                continue
        if X.size == 0:
            vec = np.zeros(n)
        elif method == 'mean':
            vec = np.mean(X,axis=0)
        elif method == 'sum':
            vec = np.sum(X,axis=0)
        return vec
    
def vectorize_corpus(model, corpus, method='mean'):
        """
        Convert all texts in a corpus to vectors
        Parameters
        ----------
        corpus: list
        List of texts    
        
        method: str
        'mean' or 'sum'
            
        Returns
        -------
        X: numpy.ndarray 
        2D Array of vectors from each text in corpus
        """
        X = [vectorize_text(model, text, method=method) for text in corpus]
        X = np.concatenate(X, axis=0).reshape(len(X),len(X[0]))
        return X

x = vectorize_corpus(w2v, 'bolsonaro é um prego')
x
# Out:
# /home/cabral/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:23: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# array([[-1.43854666, -0.1806943 , -0.85367578, ...,  1.32598948,
#          0.47914833,  1.81141376],
#        [-0.0398418 , -0.91575158, -0.09664129, ..., -0.74158543,
#         -0.59947395,  2.76774192],
#        [-1.52710843, -1.37143624,  0.1161604 , ...,  1.55695009,
#          1.02945566,  3.16802621],
#        ...,
#        [-0.18867736, -0.01199256,  0.29950196, ...,  0.3315388 ,
#          0.19968681,  0.15776226],
#        [-0.73320329, -0.6221019 ,  0.63832617, ..., -0.03713865,
#          0.13513218,  3.43924975],
#        [-0.0398418 , -0.91575158, -0.09664129, ..., -0.74158543,
#         -0.59947395,  2.76774192]])

# %%
X_train = vectorize_corpus(w2v,X_train_texts)
X_test = vectorize_corpus(w2v,X_test_texts)
# Out:
# /home/cabral/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:23: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
print('logistic regression + w2v')
clf = LogisticRegression()
clf.fit(X_train, y_train)
y_prob = clf.predict_proba(X_test)[:,1]
y_prob_train = clf.predict_proba(X_train)[:,1]
thr = optimal_threshold(y_prob_train,y_train)
print(thr)
y_pred = [1 if p >= thr else 0 for p in y_prob]
test_metrics = get_test_metrics(y_test, y_pred, y_prob, full_metrics = True)
# Out:
# logistic regression + w2v
# 0.53
#               precision    recall  f1-score   support
#
#            0       0.59      0.65      0.62       547
#            1       0.72      0.66      0.68       731
#
#     accuracy                           0.65      1278
#    macro avg       0.65      0.65      0.65      1278
# weighted avg       0.66      0.65      0.66      1278
#
# AUC:  0.7120695648694407

# %%
print('mlp + w2v')
# clf = MLPClassifier(activation = 'relu', solver = 'adam',random_state = 42, 
#                    tol = 1e-3, verbose = True, early_stopping = True, 
#                    n_iter_no_change = 3, max_iter = 100,
#                    hidden_layer_sizes = (100,), alpha = .00001, 
#                    learning_rate_init = .0001, batch_size = 32)
# hl,bs,al,lri = random_search_mlp(X_train_topics,y_train,n_iter)
# clf = optimized_mlp(hl,bs,al,lri)

# results = train_test(clf,X_train_topics,X_test_topics,y_train,y_test)

hl,bs,al,lri = random_search_mlp(X_train,y_train,n_iter=20)
clf = optimized_mlp(hl,bs,al,lri)
clf.fit(X_train,y_train)
y_prob = clf.predict_proba(X_test)[:,1]
y_prob_train = clf.predict_proba(X_train)[:,1]
thr = optimal_threshold(y_prob_train,y_train)
print(thr)
y_pred = [1 if p >= thr else 0 for p in y_prob]
test_metrics = get_test_metrics(y_test, y_pred, y_prob, full_metrics = True)
# Out:
# mlp + w2v
# 0
# hidden layers: (150,); alpha: 0.00238; learning rate: 0.03748; batch: 100
# AUC: 0.838
# 1
# hidden layers: (75, 125); alpha: 0.00002; learning rate: 0.00015; batch: 250
# AUC: 0.840
# 2
# hidden layers: (50, 175, 200); alpha: 0.00013; learning rate: 0.00506; batch: 300
# AUC: 0.829
# 3
# hidden layers: (350, 225); alpha: 0.00000; learning rate: 0.00011; batch: 200
# AUC: 0.852
# 4
# hidden layers: (25, 75); alpha: 0.00008; learning rate: 0.02528; batch: 300
# AUC: 0.844
# 5
# hidden layers: (200, 25, 50); alpha: 0.00000; learning rate: 0.06823; batch: 150
# AUC: 0.537
# 6
# hidden layers: (200,); alpha: 0.00001; learning rate: 0.02102; batch: 250
# AUC: 0.842
# 7
# hidden layers: (25, 25, 125); alpha: 0.00030; learning rate: 0.00686; batch: 250
# AUC: 0.826
# 8
# hidden layers: (125, 250); alpha: 0.00006; learning rate: 0.00691; batch: 100
# AUC: 0.836
# 9
# hidden layers: (200, 250); alpha: 0.00757; learning rate: 0.00911; batch: 200
# AUC: 0.863
# 10
# hidden layers: (75, 300, 25); alpha: 0.00002; learning rate: 0.00123; batch: 100
# AUC: 0.843
# 11
# hidden layers: (125, 300, 125); alpha: 0.00685; learning rate: 0.00909; batch: 250
# AUC: 0.852
# 12
# hidden layers: (125,); alpha: 0.00021; learning rate: 0.00175; batch: 250
# AUC: 0.846
# 13
# hidden layers: (200, 350, 150); alpha: 0.00042; learning rate: 0.00026; batch: 100
# AUC: 0.846
# 14
# hidden layers: (150,); alpha: 0.00000; learning rate: 0.00739; batch: 250
# AUC: 0.864
# 15
# hidden layers: (25, 350, 100); alpha: 0.00007; learning rate: 0.08517; batch: 300
# AUC: 0.514
# 16
# hidden layers: (25, 275); alpha: 0.00001; learning rate: 0.00023; batch: 200
# AUC: 0.836
# 17
# hidden layers: (250, 75, 100); alpha: 0.00471; learning rate: 0.00045; batch: 200
# AUC: 0.856
# 18
# hidden layers: (50,); alpha: 0.00011; learning rate: 0.05626; batch: 150
# AUC: 0.794
# 19
# hidden layers: (125, 275); alpha: 0.00001; learning rate: 0.00011; batch: 150
# AUC: 0.848
#
# --------------------
# BEST PARAMETERS (validation AUC = 0.864)
# hidden layers: (150,); alpha: 0.00000; learning rate: 0.00739; batch: 250
# --------------------
# 0.43
#               precision    recall  f1-score   support
#
#            0       0.68      0.73      0.71       547
#            1       0.79      0.74      0.77       731
#
#     accuracy                           0.74      1278
#    macro avg       0.74      0.74      0.74      1278
# weighted avg       0.74      0.74      0.74      1278
#
# AUC:  0.7983429075894632

# %% [markdown]
# # Doc2Vec

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

# documents = [TaggedDocument(doc, [i]) for i, doc in enumerate(corpus)]
# model = Doc2Vec(documents, vector_size=100, window=2, min_count=1, workers=4)
# model.save('data/2018/doc2vec.model')

doc2vec = Word2Vec.load("data/2018/doc2vec.model")

# %%
doc2vec.infer_vector(['bolsonaro','meu','ovo'])
# Out:
# array([ 6.1832638e-03,  3.5495039e-03,  5.4976359e-02, -1.3532106e-02,
#        -2.0250930e-02,  1.0158904e-02,  3.8730450e-02,  3.5195142e-02,
#         3.7984200e-02, -1.5392274e-02, -1.1900775e-02, -2.4594758e-02,
#         5.1670400e-03,  2.5606507e-02, -2.7138546e-02, -5.8211018e-03,
#        -1.5473812e-02, -1.5805205e-02,  1.0711072e-02,  4.5575999e-02,
#         1.3997402e-02, -2.5602726e-02, -5.5027967e-03,  5.1109739e-02,
#        -1.3253484e-02, -1.2299676e-02,  5.2786671e-04,  2.2672674e-02,
#        -3.3817643e-03,  1.6221507e-02, -1.7627638e-02, -3.9216679e-02,
#        -1.2693547e-02,  1.3292702e-02, -2.4766942e-02, -1.0245539e-03,
#         2.1698445e-02, -1.7661698e-02,  1.8971445e-02,  9.7888093e-03,
#        -6.7888563e-03, -2.4583496e-02, -2.5413746e-02, -1.2448537e-02,
#        -7.7623148e-03, -2.2191196e-04, -1.9227659e-02,  2.1128512e-03,
#        -5.1724808e-03,  5.1093455e-02,  2.0587651e-02, -6.2316027e-03,
#         4.3352274e-03, -1.0499034e-05,  1.0584267e-02, -1.0077548e-02,
#         1.1827714e-02, -2.5413880e-02, -6.1656949e-03, -5.4768488e-02,
#         1.4853923e-02, -1.6274264e-02, -9.2751654e-03,  3.6751218e-02,
#        -3.9316878e-02,  1.8378135e-02, -3.2925535e-02,  5.1758889e-02,
#         8.2071507e-03, -1.1972132e-02,  3.6314141e-02, -8.2323842e-02,
#         9.4256895e-03, -5.3050708e-02, -3.5256486e-02,  2.1310637e-02,
#         9.7008055e-04, -2.6178071e-02, -4.6049554e-02,  2.8044637e-02,
#        -1.5032485e-02, -3.4870747e-02, -1.1504589e-02,  2.3727024e-02,
#         3.2292933e-03,  2.8169157e-02,  1.7582796e-03, -1.6736493e-02,
#        -2.8491469e-02, -3.9296921e-02, -9.4423434e-03,  2.4512853e-03,
#        -2.6717752e-02, -6.6037752e-02,  2.0007813e-02,  3.6002137e-02,
#        -1.0945427e-02,  2.8980752e-02,  7.8299688e-03,  2.5504140e-02],
#       dtype=float32)

# %%
def vectorize_doc2vec(model,text):
    text = text.split()
    vector = model.infer_vector(text)
    return vector

def vectorize_corpus_doc2vec(model,corpus):
    X = [vectorize_doc2vec(model, text) for text in corpus]
    X = np.concatenate(X, axis=0).reshape(len(X),len(X[0]))
    return X

X_train = vectorize_corpus_doc2vec(doc2vec, X_train_texts)
X_test = vectorize_corpus_doc2vec(doc2vec, X_test_texts)

# %%
print('logistic regression + doc2vec')
clf = LogisticRegression()
clf.fit(X_train,y_train)
y_prob = clf.predict_proba(X_test)[:,1]
y_prob_train = clf.predict_proba(X_train)[:,1]
thr = optimal_threshold(y_prob_train,y_train)
y_pred = [1 if p >= thr else 0 for p in y_prob]
get_test_metrics(y_test, y_pred, y_prob, full_metrics = True)
# Out:
# logistic regression + doc2vec
#               precision    recall  f1-score   support
#
#            0       0.58      0.71      0.64       547
#            1       0.74      0.62      0.67       731
#
#     accuracy                           0.66      1278
#    macro avg       0.66      0.66      0.66      1278
# weighted avg       0.67      0.66      0.66      1278
#
# AUC:  0.7355304521366388
# (0.6572769953051644,
#  0.7413509060955519,
#  0.6403940886699507,
#  0.615595075239398,
#  0.6403940886699507,
#  0.672645739910314,
#  0.6403940886699507,
#  0.7355304521366388)

# %%
print('mlp + doc2vec')
# clf = MLPClassifier(activation = 'relu', solver = 'adam',random_state = 42, 
#                    tol = 1e-3, verbose = True, early_stopping = True, 
#                    n_iter_no_change = 3, max_iter = 100,
#                    hidden_layer_sizes = (100,), alpha = .00001, 
#                    learning_rate_init = .0001, batch_size = 32)
# hl,bs,al,lri = random_search_mlp(X_train_topics,y_train,n_iter)
# clf = optimized_mlp(hl,bs,al,lri)

# results = train_test(clf,X_train_topics,X_test_topics,y_train,y_test)

hl,bs,al,lri = random_search_mlp(X_train,y_train,n_iter=50)
clf = optimized_mlp(hl,bs,al,lri)
clf.fit(X_train,y_train)
y_prob = clf.predict_proba(X_test)[:,1]
y_prob_train = clf.predict_proba(X_train)[:,1]
thr = optimal_threshold(y_prob_train,y_train)
print(thr)
y_pred = [1 if p >= thr else 0 for p in y_prob]
test_metrics = get_test_metrics(y_test, y_pred, y_prob, full_metrics = True)
# Out:
# mlp + doc2vec
# 0
# hidden layers: (150,); alpha: 0.00238; learning rate: 0.03748; batch: 100
# AUC: 0.820
# 1
# hidden layers: (75, 125); alpha: 0.00002; learning rate: 0.00015; batch: 250
# AUC: 0.815
# 2
# hidden layers: (50, 175, 200); alpha: 0.00013; learning rate: 0.00506; batch: 300
# AUC: 0.829
# 3
# hidden layers: (350, 225); alpha: 0.00000; learning rate: 0.00011; batch: 200
# AUC: 0.825
# 4
# hidden layers: (25, 75); alpha: 0.00008; learning rate: 0.02528; batch: 300
# AUC: 0.825
# 5
# hidden layers: (200, 25, 50); alpha: 0.00000; learning rate: 0.06823; batch: 150
# AUC: 0.807
# 6
# hidden layers: (200,); alpha: 0.00001; learning rate: 0.02102; batch: 250
# AUC: 0.819
# 7
# hidden layers: (25, 25, 125); alpha: 0.00030; learning rate: 0.00686; batch: 250
# AUC: 0.819
# 8
# hidden layers: (125, 250); alpha: 0.00006; learning rate: 0.00691; batch: 100
# AUC: 0.806
# 9
# hidden layers: (200, 250); alpha: 0.00757; learning rate: 0.00911; batch: 200
# AUC: 0.808
# 10
# hidden layers: (75, 300, 25); alpha: 0.00002; learning rate: 0.00123; batch: 100
# AUC: 0.811
# 11
# hidden layers: (125, 300, 125); alpha: 0.00685; learning rate: 0.00909; batch: 250
# AUC: 0.829
# 12
# hidden layers: (125,); alpha: 0.00021; learning rate: 0.00175; batch: 250
# AUC: 0.824
# 13
# hidden layers: (200, 350, 150); alpha: 0.00042; learning rate: 0.00026; batch: 100
# AUC: 0.824
# 14
# hidden layers: (150,); alpha: 0.00000; learning rate: 0.00739; batch: 250
# AUC: 0.834
# 15
# hidden layers: (25, 350, 100); alpha: 0.00007; learning rate: 0.08517; batch: 300
# AUC: 0.787
# 16
# hidden layers: (25, 275); alpha: 0.00001; learning rate: 0.00023; batch: 200
# AUC: 0.821
# 17
# hidden layers: (250, 75, 100); alpha: 0.00471; learning rate: 0.00045; batch: 200
# AUC: 0.826
# 18
# hidden layers: (50,); alpha: 0.00011; learning rate: 0.05626; batch: 150
# AUC: 0.776
# 19
# hidden layers: (125, 275); alpha: 0.00001; learning rate: 0.00011; batch: 150
# AUC: 0.810
# 20
# hidden layers: (25,); alpha: 0.00232; learning rate: 0.00062; batch: 150
# AUC: 0.808
# 21
# hidden layers: (325,); alpha: 0.00207; learning rate: 0.00010; batch: 300
# AUC: 0.801
# 22
# hidden layers: (100, 75, 300); alpha: 0.00706; learning rate: 0.00056; batch: 200
# AUC: 0.823
# 23
# hidden layers: (275,); alpha: 0.00019; learning rate: 0.00047; batch: 250
# AUC: 0.816
# 24
# hidden layers: (25, 125); alpha: 0.00821; learning rate: 0.00022; batch: 300
# AUC: 0.798
# 25
# hidden layers: (350, 300); alpha: 0.00335; learning rate: 0.00554; batch: 300
# AUC: 0.834
# 26
# hidden layers: (250, 25, 325); alpha: 0.00044; learning rate: 0.00398; batch: 200
# AUC: 0.846
# 27
# hidden layers: (225, 25); alpha: 0.00030; learning rate: 0.00266; batch: 300
# AUC: 0.826
# 28
# hidden layers: (200, 225); alpha: 0.00003; learning rate: 0.01768; batch: 50
# AUC: 0.814
# 29
# hidden layers: (300, 175, 350); alpha: 0.00023; learning rate: 0.00528; batch: 250
# AUC: 0.828
# 30
# hidden layers: (350,); alpha: 0.00002; learning rate: 0.00046; batch: 200
# AUC: 0.821
# 31
# hidden layers: (325, 175, 100); alpha: 0.00370; learning rate: 0.02622; batch: 200
# AUC: 0.819
# 32
# hidden layers: (300,); alpha: 0.00476; learning rate: 0.01389; batch: 200
# AUC: 0.839
# 33
# hidden layers: (350, 325); alpha: 0.00297; learning rate: 0.00031; batch: 200
# AUC: 0.831
# 34
# hidden layers: (200, 150); alpha: 0.00247; learning rate: 0.02642; batch: 300
# AUC: 0.802
# 35
# hidden layers: (250, 250); alpha: 0.00003; learning rate: 0.00182; batch: 150
# AUC: 0.849
# 36
# hidden layers: (100,); alpha: 0.00798; learning rate: 0.03693; batch: 300
# AUC: 0.829
# 37
# hidden layers: (150, 50); alpha: 0.00000; learning rate: 0.00366; batch: 100
# AUC: 0.827
# 38
# hidden layers: (225, 125); alpha: 0.00000; learning rate: 0.00246; batch: 300
# AUC: 0.837
# 39
# hidden layers: (25, 225, 350); alpha: 0.00000; learning rate: 0.00031; batch: 50
# AUC: 0.802
# 40
# hidden layers: (125,); alpha: 0.00001; learning rate: 0.06348; batch: 250
# AUC: 0.814
# 41
# hidden layers: (350, 50, 50); alpha: 0.00002; learning rate: 0.00157; batch: 300
# AUC: 0.814
# 42
# hidden layers: (150, 150, 325); alpha: 0.00019; learning rate: 0.00227; batch: 200
# AUC: 0.835
# 43
# hidden layers: (200, 200); alpha: 0.00000; learning rate: 0.00201; batch: 150
# AUC: 0.855
# 44
# hidden layers: (300,); alpha: 0.00030; learning rate: 0.00424; batch: 300
# AUC: 0.837
# 45
# hidden layers: (250, 75); alpha: 0.00007; learning rate: 0.00407; batch: 200
# AUC: 0.832
# 46
# hidden layers: (250, 275); alpha: 0.00001; learning rate: 0.00976; batch: 150
# AUC: 0.805
# 47
# hidden layers: (225,); alpha: 0.00108; learning rate: 0.00091; batch: 50
# AUC: 0.824
# 48
# hidden layers: (300,); alpha: 0.00002; learning rate: 0.00362; batch: 50
# AUC: 0.834
# 49
# hidden layers: (200,); alpha: 0.00005; learning rate: 0.04529; batch: 50
# AUC: 0.813
#
# --------------------
# BEST PARAMETERS (validation AUC = 0.855)
# hidden layers: (200, 200); alpha: 0.00000; learning rate: 0.00201; batch: 150
# --------------------
# 0.49
#               precision    recall  f1-score   support
#
#            0       0.64      0.71      0.67       547
#            1       0.76      0.70      0.73       731
#
#     accuracy                           0.70      1278
#    macro avg       0.70      0.70      0.70      1278
# weighted avg       0.71      0.70      0.70      1278
#
# AUC:  0.7698702286067269
