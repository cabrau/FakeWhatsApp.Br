# %%
#utils
import emoji, re, string, time, os
from utils import get_test_metrics
from utils import preprocess
from utils import get_user_features, get_top_users
import pandas as pd
import numpy as np
from scipy.stats import randint
import pickle
import math

#nlp
import nltk
from nltk.corpus import stopwords
import spacy
from gensim.models import Word2Vec
from gensim.models.callbacks import CallbackAny2Vec

#dataviz
import matplotlib.pyplot as plt
import seaborn as sns

#features
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import linear_kernel
from sklearn import metrics
from sklearn.model_selection import train_test_split

#models
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import ComplementNB
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform

#data balancing
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import RandomOverSampler

# %matplotlib inline
sns.set(style="darkgrid")

# %%
def optimal_threshold(prob,y):
    best_thresold = 0
    best_score = 0
    
    for i in range(100):
        threshold = i/100
        y_pred = [1 if p >= threshold else 0 for p in prob]
        score = metrics.accuracy_score(y,y_pred)
        
        if score > best_score:
            #print(score)
            best_thresold = threshold
            best_score = score
            
    return best_thresold

# optimal mlp for tfidf
def get_mlp():
    clf = MLPClassifier(activation = 'relu', solver = 'adam',random_state = 42, 
                   tol = 1e-3, verbose = False, early_stopping = True, 
                   n_iter_no_change = 10, max_iter = 200,
                   hidden_layer_sizes = (100,), alpha = 0.0067, 
                   learning_rate_init = .00026, batch_size = 50)
    return clf

# tunning hyperparameters mlp
n_iter = 10
def random_layers():
    '''
    Create a tuple random of hidden_layer_sizes. 
    '''
    n_layers = np.random.randint(1,4)
    layers_list = []
    for i in range(n_layers):            
        hidden_neurons = np.random.randint(1,15)*25
        layers_list.append(hidden_neurons)
    layers_tuple = tuple(layers_list)
    return layers_tuple

def random_search_mlp(X_train,y_train,n_iter=10):
    
    # hyperparams to optimize
    hidden_layers = []
    alphas = []
    batch_sizes = []
    learning_rate_inits = []
    # sample
    np.random.seed(0)
    for i in range(n_iter):   
        hl = random_layers()
        #print(hl,end = '; ')
        hidden_layers.append(hl)
        ap = 10**np.random.uniform(-6,-2)
        #print(ap, end = '; ')
        alphas.append(ap)
        learning = 10**np.random.uniform(-4,-1)
        #print(learning, end = '; ')
        learning_rate_inits.append(learning)
        batch = np.random.randint(1,7)*50 #math.floor(10**np.random.uniform(1.5,2.6)) #np.random.randint(2,30)*10
        #print(batch)
        batch_sizes.append(batch)

    # tunning
    X_train_v, X_val, y_train_v, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=42)
    best_score = 0
    i = 0
    for hl,bs,al,lri in zip(hidden_layers,batch_sizes,alphas,learning_rate_inits):
        
        clf = optimized_mlp(hl,bs,al,lri)

        print(i, end= ' ')
        i+=1
        print()
        print('hidden layers: {a}; alpha: {b:.5f}; learning rate: {c:.5f}; batch: {d}'.format(a=hl,b=al,c=lri,d=bs))    
        clf.fit(X_train_v, y_train_v)
        y_pred = clf.predict(X_val)        
        y_prob = clf.predict_proba(X_val)[:,1]
        
        fpr, tpr, thresholds = metrics.roc_curve(y_val, y_prob, pos_label=1)
        roc_auc = metrics.auc(fpr, tpr)
        print('AUC: {a:.3f}'.format(a=roc_auc))       
        if roc_auc > best_score:
            best_score = roc_auc
            best_params = (hl,bs,al,lri)

        #print('validation rmse: {a:.3f}'.format(a=rmse))


    hl,bs,al,lri = best_params
    print()
    print('--------------------')
    print('BEST PARAMETERS (validation AUC = {a:.3f})'.format(a=best_score))
    print('hidden layers: {a}; alpha: {b:.5f}; learning rate: {c:.5f}; batch: {d}'.format(a=hl,b=al,c=lri,d=bs))
    print('--------------------')
    return hl,bs,al,lri

def optimized_mlp(hl,bs,al,lri):
    clf = MLPClassifier(activation = 'relu', solver = 'adam',random_state = 42, 
                   tol = 1e-4, verbose = False, early_stopping = True, 
                   n_iter_no_change = 10, max_iter = 100,
                   hidden_layer_sizes = hl, alpha = al, 
                   learning_rate_init = lri, batch_size = bs)
    return clf

def train_test(clf,X_train,X_test,y_train,y_test):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    y_prob = clf.predict_proba(X_test)[:,1]
    test_metrics = get_test_metrics(y_test, y_pred, y_prob, full_metrics = True)
    return test_metrics
    
def z_score(X_train,X_test):
    mu = np.mean(X_train, 0)
    sigma = np.std(X_train, 0)
    X_train = (X_train - mu ) / sigma
    X_test = (X_test - mu ) / sigma
    return X_train,X_test

# %% [markdown]
# # Load expanded data

# %%
df = pd.read_csv('data/2018/fakeWhatsApp.BR_2018.csv')
df_texts = pd.read_csv('data/2018/fakeWhatsApp.BR_2018_preprocessed_texts.csv')
df = pd.concat([df, df_texts], axis=1)
df.drop(columns=['Unnamed: 0'],inplace=True)
corpus = list(df[df['midia']==0]['preprocessed_text_lemma'].unique())
df_expanded_labels = pd.read_csv('data/2018/fakeWhatsApp.BR_2018_expanded.csv')
df['misinformation'] = df_expanded_labels['BEST_LABEL']
df.head()
# Out:
# /home/cabral/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (3,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                     id      date   hour ddi country country_iso3 ddd  \
# 0  3631133147603888180  01/08/18  13:13  55  BRASIL          BRA  17
# 1  3631133147603888180  01/08/18  13:24  55  BRASIL          BRA  17
# 2  3631133147603888180  01/08/18  13:24  55  BRASIL          BRA  17
# 3 -4391661641377612003  01/08/18  13:28  55  BRASIL          BRA  13
# 4 -4391661641377612003  09/08/18  14:46  55  BRASIL          BRA  13
#
#        state   group  midia  url  characters  words  viral  shares  \
# 0  São Paulo  2018_1      1    0          25      4      0       1
# 1  São Paulo  2018_1      0    0          58      9      1       2
# 2  São Paulo  2018_1      1    0          25      4      0       1
# 3  São Paulo  2018_1      0    0           5      1      0       1
# 4  São Paulo  2018_1      1    0          25      4      0       1
#
#                                                 text  misinformation  \
# 0                          <Arquivo de mídia oculto>              -1
# 1  O Bolsonaro tem que estar preparado pra respon...               0
# 2                          <Arquivo de mídia oculto>              -1
# 3                                              Boaaa              -1
# 4                          <Arquivo de mídia oculto>              -1
#
#                                    preprocessed_text  \
# 0                           < arquivo midia oculto >
# 1  bolsonaro estar preparado pra responder assim ...
# 2                           < arquivo midia oculto >
# 3                                              boaaa
# 4                           < arquivo midia oculto >
#
#                      preprocessed_text_stemmed  \
# 0                           < arqu mid ocult >
# 1  bolsonar est prepar pra respond assim . . .
# 2                           < arqu mid ocult >
# 3                                         boaa
# 4                           < arqu mid ocult >
#
#                              preprocessed_text_lemma
# 0                         < arquivar midia ocultar >
# 1  bolsonaro estar preparar pra responder assim ....
# 2                         < arquivar midia ocultar >
# 3                                              boaaa
# 4                         < arquivar midia ocultar >

# %% [markdown]
# # Sorting and selecting data

# %%
# sorting by time
def custom_time(data,hora):
    string = data + " " + hora
    return string

df['timestamp'] = df.apply(lambda x: custom_time(x['date'],x['hour']),axis=1)
df['timestamp'] = pd.to_datetime(df['timestamp'], format='%d/%m/%y %H:%M')
#df.sort_values(by='timestamp',inplace=True)

# %%
# preserve duplicates
df_pre_filter = df.copy()
df_pre_filter = df_pre_filter[df['midia']==0]
# filter noisy messages
df_pre_filter['types_chars'] = [len(set(t)) for t in df_pre_filter['text']]
df_pre_filter = df_pre_filter[df_pre_filter['types_chars']>15]

# include in viral category automatically labeled messages
df_pre_filter['viral'] = [1 if mis!=-1 else 0 for mis,vir in zip(df_pre_filter['misinformation'],df_pre_filter['viral'])]
df_pre_filter = df_pre_filter[df_pre_filter['viral']==1]

df_pre_filter.reset_index(drop=True,inplace=True)

# %%
#removing duplicates and selecting only labelled data
df = df.drop_duplicates(subset=['text'])
df = df[df['midia']==0]

# filter noisy messages
df = df[df['words']>10]
df['types_chars'] = [len(set(t)) for t in df['text']]
df = df[df['types_chars']>15]

# include in viral category automatically labeled messages
df['viral'] = [1 if mis!=-1 else 0 for mis,vir in zip(df['misinformation'],df['viral'])]
df = df[df['viral']==1]

df.reset_index(drop=True,inplace=True)
print('manual:',len(df[df['shares']>1]))
print('expansion:',len(df))
print('number of expanded samples:',len(df[df['shares']==1]))
df.tail()
# Out:
# manual: 4470
# expansion: 6790
# number of expanded samples: 2320
#                        id      date   hour ddi country country_iso3 ddd  \
# 6785 -5542692723449689572  28/10/18  19:24  55  BRASIL          BRA  73
# 6786 -6076734346383138898  28/10/18  19:27  55  BRASIL          BRA  47
# 6787  4701292237751769642  28/10/18  19:32  55  BRASIL          BRA  75
# 6788  2485357201479715834  28/10/18  21:53  55  BRASIL          BRA  62
# 6789   657760642306071754  28/10/18  22:19  55  BRASIL          BRA  63
#
#                state    group  midia  ...  words  viral  shares  \
# 6785           Bahia  2018_44      0  ...     24      1       2
# 6786  Santa Catarina  2018_39      0  ...     25      1       2
# 6787           Bahia   2018_9      0  ...    256      1       2
# 6788           Goiás  2018_56      0  ...    161      1       1
# 6789       Tocantins   2018_8      0  ...     12      1       2
#
#                                                    text  misinformation  \
# 6785  Que Deus ilumine o novo presidente. É um alívi...               0
# 6786  Contra TD e contra todos... Mostramos q o Bras...               0
# 6787  *🤝🏻🇧🇷BOLSONARO PRESIDENTE🇧🇷🤝🏻*\n*🤝🏻🇧🇷BOLSONARO...               0
# 6788  OLHA O QUANTO AVANÇAMOS! SE LIGA NESSA LIMPEZA...               1
# 6789  Alguem  tirou fotos do boletim de urna? Podem ...               1
#
#                                       preprocessed_text  \
# 6785  deus ilumine novo presidente . alivio sabermos...
# 6786  contra td contra todos . . . mostramos q brasi...
# 6787  * 🤝 🏻 🇧 🇷 bolsonaro presidente 🇧 🇷 🤝 🏻 * \n * ...
# 6788  olha quanto avancamos ! liga nessa limpeza ! e...
# 6789  alguem tirou fotos boletim urna ? podem enviar...
#
#                               preprocessed_text_stemmed  \
# 6785  deu ilumin nov presid . alivi sab encerr cicl ...
# 6786  contr td contr tod . . . mostr q brasil . . . ...
# 6787  * 🤝 🏻 🇧 🇷 bolsonar presid 🇧 🇷 🤝 🏻 * \n * 🤝 🏻 🇧...
# 6788  olh quant avanc ! lig ness limp ! esta : \n \n...
# 6789     algu tir fot boletim urn ? pod envi mim ? grat
#
#                                 preprocessed_text_lemma           timestamp  \
# 6785  deus iluminar novo presidente . aliviar saber ... 2018-10-28 19:24:00
# 6786  contra td contra todo . . . mostrar q brasil .... 2018-10-28 19:27:00
# 6787  * 🤝 🏻 🇧 🇷 bolsonaro presidente 🇧 🇷 🤝 🏻 * \n * ... 2018-10-28 19:32:00
# 6788  olhar quantum avancamos ! ligar nessa limpeza ... 2018-10-28 21:53:00
# 6789  alguem tirar foto boletim urna ? poder enviar ... 2018-10-28 22:19:00
#
#      types_chars
# 6785          25
# 6786          26
# 6787          19
# 6788          73
# 6789          22
#
# [5 rows x 22 columns]

# %% [markdown]
# # Select texts and labels

# %%
# select data
#texts
# original_texts = df['text']
# texts = df['preprocessed_text_lemma']
# users_ids = df['id']
X = df[['text', 'preprocessed_text','preprocessed_text_lemma', 'url','shares']]
#target
y = df['misinformation']

# %%
def print_class_balance(y):
    pos_mask = y == 1 
    pos = y[pos_mask]
    neg_mask = y == 0 
    neg = y[neg_mask]
    values = [pos.shape[0],neg.shape[0]]
    keys = ['misinformation', 'non-misinformation']
    g = sns.barplot(x = keys, y = values)
    for p in g.patches:
        g.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., 
                                                   p.get_height()), ha = 'center', 
                   va = 'center', xytext = (0, 5), textcoords = 'offset points')
print('data balance in dataset')        
print_class_balance(y)
# Out:
# data balance in dataset

# %% [markdown]
# # User graph features

# %%
df_users = pd.read_csv('data/2018/users.csv')
print(len(df_users))
df_users.sort_values('viral_misinformation_ratio', ascending=False).head(3)
# Out:
# 5364
#                        id  groups  number_of_messages  texts  text_ratio  \
# 4669 -8996328134268937741       1                   2      2    1.000000
# 2031  8140300529440159518       1                  23     13    0.565217
# 4474 -3816863652331327511       2                   2      2    1.000000
#
#       midia  midia_ratio  virals  viral_ratio  degree_centrality  strenght  \
# 4669      0     0.000000       1     0.500000                199       398
# 2031     10     0.434783       4     0.173913                307      7061
# 4474      0     0.000000       2     1.000000                283       329
#
#       viral_degree_centrality  viral_strenght  misinformation  \
# 4669                       92              92               1
# 2031                      169             676               4
# 4474                      116             140               2
#
#       misinformation_degree_centrality  misinformation_strenght  \
# 4669                                66                     66.0
# 2031                               126                    504.0
# 4474                                78                     91.0
#
#       misinformation_ratio  viral_misinformation_ratio  \
# 4669              0.500000                         1.0
# 2031              0.173913                         1.0
# 4474              1.000000                         1.0
#
#                                          viral_messages
# 4669  enquete presidencia ! * candidatar ? * votar v...
# 2031  * 🚨 urgente ! ! ! * \n \n presidiario lula aut...
# 4474  💳 trabalhar melhor 💳 \n \n trabalhar cartoes c...

# %%
df_active_users = df_users[(df_users['virals'] > 0)]
user_features = ['number_of_messages','midia_ratio', 'viral_ratio', 
                 'degree_centrality', 'strenght',
                 'viral_degree_centrality', 'viral_strenght']
df_active_users = df_active_users[user_features+['id']]
df_active_users
# Out:
#       number_of_messages  midia_ratio  viral_ratio  degree_centrality  \
# 0                   4396     0.148772     0.013876                152
# 1                   2332     0.583190     0.110206               1640
# 2                   2064     0.540698     0.119186                525
# 3                   2020     0.214356     0.063366                738
# 4                   1810     0.542541     0.063536                152
# ...                  ...          ...          ...                ...
# 5250                   1     0.000000     1.000000                139
# 5283                   1     0.000000     1.000000                164
# 5286                   1     0.000000     1.000000                307
# 5314                   1     0.000000     1.000000                272
# 5350                   1     0.000000     1.000000                277
#
#       strenght  viral_degree_centrality  viral_strenght                   id
# 0       668192                       96            5856 -3818310068976662355
# 1       498105                      936           30402  5782050016593913959
# 2       389426                      307           25786 -2072140886659020977
# 3       644385                      415           19752  2839535797075678550
# 4       275120                       96           11040   170916900626840870
# ...        ...                      ...             ...                  ...
# 5250       139                       73              73 -5214655400732106639
# 5283       164                       68              68 -2988991460937333560
# 5286       307                      169             169  1501291910995669365
# 5314       272                      125             125 -3747724602765618241
# 5350       277                      146             146  4898420356259657973
#
# [2826 rows x 8 columns]

# %%
def users_in_list(user,user_list):
    if user in user_list:
        return True
    else:
        return False
    
df_users_features = pd.DataFrame(columns = user_features)

for text in X['text']:
    users_that_shared = df_pre_filter[df_pre_filter['text']==text]['id'].unique()
    df_users_in_list = df_active_users[df_active_users.apply(lambda x: users_in_list(x['id'],users_that_shared),axis=1)]
    df_users_in_list = df_users_in_list[user_features]
    df_users_in_list = df_users_in_list.median().to_frame().transpose()
    df_users_features = pd.concat([df_users_features,df_users_in_list])
df_users_features
# Out:
#     number_of_messages  midia_ratio  viral_ratio  degree_centrality  strenght  \
# 0                 31.0     0.870968     0.032258               43.0    1333.0
# 0               2064.0     0.540698     0.119186              525.0  389426.0
# 0                340.0     0.217647     0.229412              269.0   91460.0
# 0                 78.0     0.358974     0.397436              631.0   13394.0
# 0                 63.0     0.444444     0.190476               89.0    3798.0
# ..                 ...          ...          ...                ...       ...
# 0                 42.0     0.428571     0.261905               88.0    3696.0
# 0                 14.0     0.214286     0.071429              305.0    4270.0
# 0                 98.0     0.438776     0.091837              187.0   18326.0
# 0                327.0     0.752294     0.073394               94.0   30738.0
# 0                 98.0     0.744898     0.091837              585.0   15278.0
#
#     viral_degree_centrality  viral_strenght
# 0                      31.0            31.0
# 0                     307.0         25786.0
# 0                     160.0         12480.0
# 0                     366.0          3207.0
# 0                      51.0           428.0
# ..                      ...             ...
# 0                      44.0           484.0
# 0                     186.0           186.0
# 0                     102.0           918.0
# 0                      58.0          1392.0
# 0                     329.0           500.0
#
# [6790 rows x 7 columns]

# %%
df_users_features.reset_index(drop=True,inplace=True)
df_users_features
# Out:
#       number_of_messages  midia_ratio  viral_ratio  degree_centrality  \
# 0                   31.0     0.870968     0.032258               43.0
# 1                 2064.0     0.540698     0.119186              525.0
# 2                  340.0     0.217647     0.229412              269.0
# 3                   78.0     0.358974     0.397436              631.0
# 4                   63.0     0.444444     0.190476               89.0
# ...                  ...          ...          ...                ...
# 6785                42.0     0.428571     0.261905               88.0
# 6786                14.0     0.214286     0.071429              305.0
# 6787                98.0     0.438776     0.091837              187.0
# 6788               327.0     0.752294     0.073394               94.0
# 6789                98.0     0.744898     0.091837              585.0
#
#       strenght  viral_degree_centrality  viral_strenght
# 0       1333.0                     31.0            31.0
# 1     389426.0                    307.0         25786.0
# 2      91460.0                    160.0         12480.0
# 3      13394.0                    366.0          3207.0
# 4       3798.0                     51.0           428.0
# ...        ...                      ...             ...
# 6785    3696.0                     44.0           484.0
# 6786    4270.0                    186.0           186.0
# 6787   18326.0                    102.0           918.0
# 6788   30738.0                     58.0          1392.0
# 6789   15278.0                    329.0           500.0
#
# [6790 rows x 7 columns]

# %%
X_with_users = pd.concat([X, df_users_features],axis=1)
X_with_users.head()
# Out:
#                                                 text  \
# 0  O dia em que ex-guerrilheiro, militantes e des...
# 1  O nível dos jornalistas do programa Roda Viva ...
# 2  *Atenção*\n\nPrecisamos da ajuda de todos você...
# 3  Gestão do colombiano na capital, imagina ele n...
# 4  🛑🛑🛑🛑🛑🛑\nInterrompendo momentaneamente a conver...
#
#                              preprocessed_text_lemma  url  shares  \
# 0  dia ex - guerrilheiro , militante desarmamenti...    0       1
# 1  nivel jornalista programarr rodar vivo tao bai...    0       3
# 2  * atencao * \n \n precisar ajudar todo voces *...    0       2
# 3  gestao colombiano capital , imaginar governar ...    0       5
# 4  🛑 🛑 🛑 🛑 🛑 🛑 \n interromper momentaneamente con...    0       2
#
#    number_of_messages  midia_ratio  viral_ratio  degree_centrality  strenght  \
# 0                31.0     0.870968     0.032258               43.0    1333.0
# 1              2064.0     0.540698     0.119186              525.0  389426.0
# 2               340.0     0.217647     0.229412              269.0   91460.0
# 3                78.0     0.358974     0.397436              631.0   13394.0
# 4                63.0     0.444444     0.190476               89.0    3798.0
#
#    viral_degree_centrality  viral_strenght
# 0                     31.0            31.0
# 1                    307.0         25786.0
# 2                    160.0         12480.0
# 3                    366.0          3207.0
# 4                     51.0           428.0

# %%
X_with_users.to_csv('data/2018/fakeWhatsApp.BR_2018_propagation.csv',index=False)

# %% [markdown]
# # After preprocessing the first time, we can start from here

# %%
X = pd.read_csv('data/2018/fakeWhatsApp.BR_2018_propagation.csv')
user_features = ['number_of_messages','midia_ratio', 'viral_ratio', 
                 'degree_centrality', 'strenght',
                 'viral_degree_centrality', 'viral_strenght']
X.head()
# Out:
#                                                 text  \
# 0  O dia em que ex-guerrilheiro, militantes e des...
# 1  O nível dos jornalistas do programa Roda Viva ...
# 2  *Atenção*\n\nPrecisamos da ajuda de todos você...
# 3  Gestão do colombiano na capital, imagina ele n...
# 4  🛑🛑🛑🛑🛑🛑\nInterrompendo momentaneamente a conver...
#
#                              preprocessed_text_lemma  url  shares  \
# 0  dia ex - guerrilheiro , militante desarmamenti...    0       1
# 1  nivel jornalista programarr rodar vivo tao bai...    0       3
# 2  * atencao * \n \n precisar ajudar todo voces *...    0       2
# 3  gestao colombiano capital , imaginar governar ...    0       5
# 4  🛑 🛑 🛑 🛑 🛑 🛑 \n interromper momentaneamente con...    0       2
#
#    number_of_messages  midia_ratio  viral_ratio  degree_centrality  strenght  \
# 0                31.0     0.870968     0.032258               43.0    1333.0
# 1              2064.0     0.540698     0.119186              525.0  389426.0
# 2               340.0     0.217647     0.229412              269.0   91460.0
# 3                78.0     0.358974     0.397436              631.0   13394.0
# 4                63.0     0.444444     0.190476               89.0    3798.0
#
#    viral_degree_centrality  viral_strenght  \
# 0                     31.0            31.0
# 1                    307.0         25786.0
# 2                    160.0         12480.0
# 3                    366.0          3207.0
# 4                     51.0           428.0
#
#                                    preprocessed_text
# 0  dia ex - guerrilheiro , militantes desarmament...
# 1  nivel jornalistas programa roda viva tao baixo...
# 2  * atencao * \n \n precisamos ajuda todos voces...
# 3  gestao colombiano capital , imagina governo , ...
# 4  🛑 🛑 🛑 🛑 🛑 🛑 \n interrompendo momentaneamente c...

# %% [markdown]
# # Train-test split by time

# %%
a = ['esse é um texto doidera!','...esse texto é peba?']
for x in a:
    x = list(x)
    x = [i for i in x if i not in punct]
    x = [' '.join(i) for i in x]
    print(x)
# Out:
# ['e', 's', 's', 'e', ' ', 'é', ' ', 'u', 'm', ' ', 't', 'e', 'x', 't', 'o', ' ', 'd', 'o', 'i', 'd', 'e', 'r', 'a']
# ['e', 's', 's', 'e', ' ', 't', 'e', 'x', 't', 'o', ' ', 'é', ' ', 'p', 'e', 'b', 'a']

# %%
# use only characters
# texts = df['text']
# texts = [' '.join(list(t)) for t in texts]
import string
punct = list(string.punctuation) 

def break_in_chars(texts):
    texts = [' '.join(list(t)) for t in texts]
    return texts


# train with the 80% older messages; test with the 20% newer
# split by time
# cut index
cut = math.floor(len(X)*0.8)
print('cut:',cut)

X_train = X[0:cut]
y_train= y[0:cut]
X_test = X[cut:]
y_test = y[cut:]

print('train')
print_class_balance(y_train)
plt.figure()
print('test')
print_class_balance(y_test)
# Out:
# cut: 5432
# train
# test

# %% [markdown]
# # Baseline

# %%
# ONLY TEXT - MUST OVERCOME THIS

X_train_texts_bow = X_train['preprocessed_text_lemma']
X_test_texts_bow = X_test['preprocessed_text_lemma']

# cut emoji and puctuation
vectorizer = CountVectorizer(max_features = None, ngram_range = (1,3), #(1,3) 
                             lowercase = True, binary=True)

vectorizer.fit(X_train_texts_bow)

X_train_bow = vectorizer.transform(X_train_texts_bow)
X_test_bow = vectorizer.transform(X_test_texts_bow)


print('logistic regression + binary bow')
clf = LogisticRegression(max_iter = 200)
clf.fit(X_train_bow, y_train)

y_prob = clf.predict_proba(X_test_bow)[:,1]
y_prob_train = clf.predict_proba(X_train_bow)[:,1]
# threshold moving

#thr = optimal_threshold(y_prob,y_test)
thr = optimal_threshold(y_prob_train,y_train)
print(thr)
y_pred = [1 if p >= 0.40 else 0 for p in y_prob]
get_test_metrics(y_test, y_pred, y_prob, full_metrics = True)
# Out:
# logistic regression + binary bow
# 0.45
#               precision    recall  f1-score   support
#
#            0       0.80      0.82      0.81       655
#            1       0.83      0.81      0.82       703
#
#     accuracy                           0.82      1358
#    macro avg       0.82      0.82      0.82      1358
# weighted avg       0.82      0.82      0.82      1358
#
# AUC:  0.903686490829922
# (0.8173784977908689,
#  0.8321167883211679,
#  0.8132530120481928,
#  0.8108108108108109,
#  0.8132530120481928,
#  0.8213256484149856,
#  0.8132530120481928,
#  0.903686490829922)

# %%
X_train_texts_bow = X_train['preprocessed_text_lemma']
X_test_texts_bow = X_test['preprocessed_text_lemma']

cut = math.floor(0.9*len(X_train_texts_bow))

X_train_texts_bow_train = X_train_texts_bow[0:cut]
X_train_texts_bow_val = X_train_texts_bow[cut:]
y_train_val = y_train[0:cut]
y_val = y_train[cut:]

# %%
# ONLY TEXT - MUST OVERCOME THIS
# cut emoji and puctuation
ngrams = [(1,1),(1,2),(1,3),(2,2),(2,3),(3,3),(2,4),(4,4)]

best_ngram = ngrams[0]
best_score = 0

for ngram in ngrams:
    vectorizer = CountVectorizer(max_features = None, ngram_range = ngram, #(1,3) 
                                 lowercase = True, binary=True)

    vectorizer.fit(X_train_texts_bow_train)

    X_train_bow = vectorizer.transform(X_train_texts_bow_train)
    X_test_bow = vectorizer.transform(X_train_texts_bow_val)

    print('logistic regression + binary bow', ngram)
    clf = LogisticRegression(max_iter = 200)
    clf.fit(X_train_bow, y_train_val)

    y_prob = clf.predict_proba(X_test_bow)[:,1]
    y_prob_train = clf.predict_proba(X_train_bow)[:,1]
    # threshold moving

    #thr = optimal_threshold(y_prob,y_test)
    thr = optimal_threshold(y_prob_train,y_train_val)
    y_pred = [1 if p >= thr else 0 for p in y_prob]
    score = metrics.accuracy_score(y_val,y_pred)
    if score > best_score:
        best_score = score        
        best_ngram = ngram
        print(best_score,ngram)
        
print('final result', best_score, best_ngram)
# Out:
# logistic regression + binary bow (1, 1)
# 0.8033088235294118 (1, 1)
# logistic regression + binary bow (1, 2)
# 0.8143382352941176 (1, 2)
# logistic regression + binary bow (1, 3)
# logistic regression + binary bow (2, 2)
# logistic regression + binary bow (2, 3)
# logistic regression + binary bow (3, 3)
# logistic regression + binary bow (2, 4)
# logistic regression + binary bow (4, 4)
# final result 0.8143382352941176 (1, 2)

# %% [markdown]
# # Bag of Characters

# %%
type(X_train_texts)
# Out:
# list

# %%
# X_train_texts = break_in_chars(X_train['text'])
# X_test_texts = break_in_chars(X_test['text'])

X_train_texts = (X_train['preprocessed_text_lemma'])
X_test_texts = (X_test['preprocessed_text_lemma'])

X_train_users = X_train[user_features + ['url','shares']].to_numpy() #user_features +
X_test_users = X_test[user_features + ['url','shares']].to_numpy() # user_features + 

vectorizer = TfidfVectorizer(max_features = 5000, ngram_range = (1,1), lowercase = True, token_pattern = r'[^\s]+')

vectorizer = CountVectorizer(max_features = 1000, ngram_range = (1,1), binary=True)

vectorizer.fit(X_train_texts)   
X_train_bow = vectorizer.transform(X_train_texts)
X_test_bow = vectorizer.transform(X_test_texts)

X_train_bow = X_train_bow.todense()
X_test_bow = X_test_bow.todense()

print(X_train_bow.shape)

# get user and propagation features
X_train_users, X_test_users = z_score(X_train_users, X_test_users)
print(X_train_users.shape)
X_train_array = np.concatenate((X_train_bow, X_train_users), axis=1)
X_test_array  = np.concatenate((X_test_bow, X_test_users), axis=1)
print(X_train_array.shape)
# Out:
# (5432, 1000)
# (5432, 9)
# (5432, 1009)

# %%
print(vectorizer.get_feature_names())
# Out:
# ['abaixar', 'abortar', 'abrir', 'absurdo', 'acabar', 'acao', 'aceitar', 'acesse', 'achar', 'acima', 'acompanhar', 'acontecer', 'acordar', 'acre', 'acreditar', 'acusar', 'adelio', 'adesivaco', 'adesivo', 'adquirir', 'advogar', 'afinal', 'afirmar', 'agora', 'aguar', 'ai', 'ainda', 'ajudar', 'alagoa', 'alar', 'alckmin', 'algo', 'alguem', 'algum', 'aliar', 'alto', 'aluno', 'alvaro', 'alves', 'amanhar', 'amar', 'amazona', 'ameaca', 'america', 'americano', 'amigar', 'amigo', 'amoedar', 'amor', 'analisar', 'andar', 'ano', 'antar', 'antonio', 'anular', 'anunciar', 'aparecer', 'apenas', 'aplicar', 'apo', 'apoiadores', 'apoiar', 'aprender', 'apresentar', 'aprovar', 'aproximadamente', 'aproximar', 'aqui', 'ar', 'armar', 'artigo', 'artista', 'assaltar', 'assassinar', 'assassino', 'assim', 'assinar', 'assistir', 'assumir', 'assunto', 'atacar', 'atar', 'atarncao', 'atencao', 'atentar', 'atingir', 'atos', 'atrapalhar', 'atraves', 'atro', 'atual', 'audiencia', 'audio', 'augusto', 'aula', 'aumentar', 'autor', 'auxiliar', 'avisar', 'bahia', 'baixar', 'banco', 'bandeiro', 'bandido', 'base', 'basto', 'bater', 'beber', 'bem', 'beneficiar', 'bilhoes', 'bolsar', 'bolsonaro', 'bom', 'boulos', 'br', 'branco', 'brasil', 'brasileiro', 'brasilia', 'brigar', 'buscar', 'cabo', 'cada', 'cadeia', 'cair', 'caixa', 'camara', 'caminhar', 'camisa', 'camiseta', 'campanha', 'campar', 'canal', 'candidatar', 'candidatars', 'candidato', 'candidatura', 'capacidade', 'capaz', 'capital', 'capitao', 'cargo', 'carlos', 'caro', 'carreata', 'carro', 'cartar', 'carvalho', 'casar', 'casarr', 'causar', 'cear', 'celular', 'central', 'centrar', 'cercar', 'certar', 'certeza', 'cesar', 'chamar', 'chance', 'chat', 'chefe', 'chegar', 'cidadao', 'cidade', 'cima', 'ciro', 'citar', 'civil', 'claro', 'clicar', 'coisa', 'colar', 'colocar', 'comandar', 'combater', 'comecar', 'comecou', 'comentar', 'comer', 'cometer', 'compartilhar', 'competencia', 'comprar', 'comum', 'comunicacao', 'comunismo', 'comunista', 'condenar', 'conferir', 'confirmar', 'congresso', 'conhecer', 'conhecimento', 'conseguir', 'conselho', 'considerar', 'constitucional', 'constituicao', 'contar', 'contatos', 'continuar', 'contra', 'contrariar', 'contratar', 'conversar', 'convidar', 'convocar', 'copiar', 'cor', 'coracao', 'coragem', 'coronel', 'correr', 'corrupcao', 'corrupto', 'cortar', 'costa', 'cotar', 'creditar', 'crescer', 'crianca', 'criancas', 'criar', 'crime', 'criminoso', 'cristao', 'cristaos', 'criticar', 'cubar', 'cuidar', 'cujo', 'cultura', 'cumprir', 'custar', 'daciolo', 'daqui', 'dar', 'debater', 'decidir', 'declarar', 'dedo', 'defender', 'defenderr', 'defeso', 'deg', 'deixar', 'delegar', 'demais', 'democracia', 'demonstrar', 'dentro', 'denunciar', 'depender', 'deputar', 'derrotar', 'derrubar', 'desarmamento', 'descobrir', 'desde', 'desejar', 'desempregar', 'desesperar', 'dessar', 'desta', 'destacar', 'destinar', 'deus', 'dever', 'deverr', 'df', 'dia', 'diante', 'diferenca', 'dilma', 'dinheiro', 'direito', 'discutir', 'disputar', 'disso', 'distribuir', 'ditador', 'ditadura', 'diverso', 'dividir', 'divulgar', 'dizer', 'dizerer', 'dois', 'dominar', 'domingo', 'dono', 'dr', 'drogar', 'durante', 'duvidar', 'economia', 'economica', 'economista', 'eduardo', 'educacao', 'eis', 'eleger', 'eleicao', 'eleicoes', 'eleito', 'eleitor', 'eleitoral', 'elenao', 'empregar', 'empresar', 'encerrar', 'encontrar', 'enfim', 'enquanto', 'ensinar', 'entao', 'entender', 'entrar', 'entregar', 'entrevisto', 'enviar', 'envolver', 'epoca', 'equipar', 'errar', 'escola', 'escolher', 'escrever', 'escutar', 'espalhar', 'esperanca', 'esperar', 'espiritar', 'esquerdista', 'esquerdo', 'esquererdo', 'estadual', 'estao', 'estar', 'estara', 'estatal', 'estrategia', 'estruturar', 'estudar', 'estupradores', 'estuprar', 'etc', 'eua', 'evento', 'evitar', 'ex', 'exatamente', 'exemplo', 'exercitar', 'existir', 'experiencia', 'explicar', 'expor', 'fabio', 'faca', 'facebook', 'faculdade', 'fake', 'falar', 'falir', 'falso', 'faltar', 'falto', 'familia',  ...

# %%
print('logistic regression + boc + user features')
clf = LogisticRegression(max_iter=200)
clf.fit(X_train_array,y_train)

y_prob = clf.predict_proba(X_test_array)[:,1]
y_prob_train = clf.predict_proba(X_train_array)[:,1]
# threshold moving

#thr = optimal_threshold(y_prob,y_test)
thr = optimal_threshold(y_prob_train,y_train)
print(thr)
y_pred = [1 if p >= thr else 0 for p in y_prob]
get_test_metrics(y_test, y_pred, y_prob, full_metrics = True)
# Out:
# logistic regression + boc + user features
# 0.49
#               precision    recall  f1-score   support
#
#            0       0.72      0.75      0.73       655
#            1       0.76      0.73      0.74       703
#
#     accuracy                           0.74      1358
#    macro avg       0.74      0.74      0.74      1358
# weighted avg       0.74      0.74      0.74      1358
#
# AUC:  0.8149805088334617
# (0.7378497790868925,
#  0.7570370370370371,
#  0.7339312406576981,
#  0.7268847795163584,
#  0.7339312406576981,
#  0.741654571843251,
#  0.7339312406576981,
#  0.8149805088334617)

# %%
print('logistic regression + user features')
clf = MLPClassifier()
clf.fit(X_train_users,y_train)

y_prob = clf.predict_proba(X_test_users)[:,1]
y_prob_train = clf.predict_proba(X_train_users)[:,1]
# threshold moving

#thr = optimal_threshold(y_prob,y_test)
thr = optimal_threshold(y_prob_train,y_train)
print(thr)
y_pred = [1 if p >= thr else 0 for p in y_prob]
get_test_metrics(y_test, y_pred, y_prob, full_metrics = True)
# Out:
# logistic regression + user features
# 0.48
#               precision    recall  f1-score   support
#
#            0       0.54      0.55      0.54       655
#            1       0.57      0.56      0.57       703
#
#     accuracy                           0.55      1358
#    macro avg       0.55      0.55      0.55      1358
# weighted avg       0.55      0.55      0.55      1358
#
# AUC:  0.5652753195139695
# (0.5544918998527246,
#  0.5706051873198847,
#  0.5413191811978773,
#  0.5633001422475107,
#  0.5413191811978773,
#  0.5669291338582677,
#  0.5413191811978773,
#  0.5652753195139695)

# %%
print('mlp + bow + user features')
clf = MLPClassifier(activation = 'relu', solver = 'adam',random_state = 42, 
                   tol = 1e-3, verbose = False, early_stopping = True, 
                   n_iter_no_change = 3, max_iter = 200,
                   hidden_layer_sizes = (100,), alpha = .00001, 
                   learning_rate_init = .0001, batch_size = 200)

clf.fit(X_train,y_train)

y_prob = clf.predict_proba(X_test)[:,1]
y_prob_train = clf.predict_proba(X_train)[:,1]
# threshold moving
thr = optimal_threshold(y_prob_train,y_train)
print(thr)
y_pred = [1 if p >= thr else 0 for p in y_prob]
get_test_metrics(y_test, y_pred, y_prob, full_metrics = True)
# Out:
# mlp + bow + user features
# 0.49
#               precision    recall  f1-score   support
#
#            0       0.66      0.69      0.68       655
#            1       0.70      0.67      0.68       703
#
#     accuracy                           0.68      1358
#    macro avg       0.68      0.68      0.68      1358
# weighted avg       0.68      0.68      0.68      1358
#
# AUC:  0.7649919103514924
# (0.6796759941089838,
#  0.6994047619047619,
#  0.6756152125279643,
#  0.6685633001422475,
#  0.6756152125279643,
#  0.6836363636363636,
#  0.6756152125279643,
#  0.7649919103514924)

# %% [markdown]
# # Topic modelling (LDA)

# %%
# # topics
# from gensim.models import LdaModel
# from gensim.corpora.dictionary import Dictionary
# n_topics = 15

# def train_lda(corpus, n_topics = 100):
#     common_texts = [x.split() for x in corpus]
#     common_dictionary = Dictionary(common_texts)
#     common_corpus = [common_dictionary.doc2bow(text) for text in common_texts]
#     lda = LdaModel(common_corpus, num_topics=n_topics)
#     return lda, common_dictionary

# lda, common_dictionary = train_lda(X_train_texts, n_topics)

# %%
# # vectorizing
# def tup2array(tuples,n_topics):
#     topics = np.zeros(n_topics)
#     for t, p in tuples:
#         topics[t] = p
#     return topics

# def vectorize_topics(X,lda):
#     X = [lda[x] for x in X]
#     X = [tup2array(v,lda.num_topics) for v in X]
#     return X

# def texts2topics(texts,lda):
#     X = [x.split() for x in texts]
#     X = [common_dictionary.doc2bow(text) for text in X]
#     X = vectorize_topics(X,lda)
#     return X
    

# X_train_topics = texts2topics(X_train_texts,lda)
# X_test_topics = texts2topics(X_test_texts,lda)

# %%
# print('logistic regression + lda')
# clf = LogisticRegression()
# clf.fit(X_train_topics,y_train)
# y_prob = clf.predict_proba(X_test_topics)[:,1]
# y_prob_train = clf.predict_proba(X_train_topics)[:,1]
# thr = optimal_threshold(y_prob_train,y_train)
# print(thr)
# y_pred = [1 if p >= thr else 0 for p in y_prob]
# test_metrics = get_test_metrics(y_test, y_pred, y_prob, full_metrics = True)

# %%
# print('mlp + lda')
# # clf = MLPClassifier(activation = 'relu', solver = 'adam',random_state = 42, 
# #                    tol = 1e-3, verbose = True, early_stopping = True, 
# #                    n_iter_no_change = 3, max_iter = 100,
# #                    hidden_layer_sizes = (100,), alpha = .00001, 
# #                    learning_rate_init = .0001, batch_size = 32)
# # hl,bs,al,lri = random_search_mlp(X_train_topics,y_train,n_iter)
# # clf = optimized_mlp(hl,bs,al,lri)

# # results = train_test(clf,X_train_topics,X_test_topics,y_train,y_test)

# hl,bs,al,lri = random_search_mlp(X_train_topics,y_train,n_iter)
# clf = optimized_mlp(hl,bs,al,lri)
# clf.fit(X_train_topics,y_train)
# y_prob = clf.predict_proba(X_test_topics)[:,1]
# y_prob_train = clf.predict_proba(X_train_topics)[:,1]
# thr = optimal_threshold(y_prob_train,y_train)
# print(thr)
# y_pred = [1 if p >= thr else 0 for p in y_prob]
# test_metrics = get_test_metrics(y_test, y_pred, y_prob, full_metrics = True)

# %% [markdown]
# # Word embeddings

# %%
from gensim.models import Word2Vec
from gensim.models.callbacks import CallbackAny2Vec

# %%
len(corpus)
# Out:
# 99016

# %%
class EpochLogger(CallbackAny2Vec):
    """Callback to log information about training"""

    def __init__(self):
        self.epoch = 0

    def on_epoch_begin(self, model):
        self.epoch += 1
        print("W2V: Epoch #{}".format(self.epoch))
        
epoch_logger = EpochLogger()

w2v = Word2Vec(min_count=1)
w2v.build_vocab(corpus)  # prepare the model vocabulary
w2v.train(corpus, total_examples=w2v.corpus_count, 
            epochs=15, compute_loss=True, 
            callbacks=[epoch_logger])

w2v.save("data/2018/word2vec_train.model")

w2v = Word2Vec.load("data/2018/word2vec_train.model")
# Out:
# W2V: Epoch #1
# W2V: Epoch #2
# W2V: Epoch #3
# W2V: Epoch #4
# W2V: Epoch #5
# W2V: Epoch #6
# W2V: Epoch #7
# W2V: Epoch #8
# W2V: Epoch #9
# W2V: Epoch #10
# W2V: Epoch #11
# W2V: Epoch #12
# W2V: Epoch #13
# W2V: Epoch #14
# W2V: Epoch #15

# %%
w2v.most_similar(positive=['deus'])
# Out:
# /home/cabral/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('dars', 0.7146254181861877),
#  ('vosso', 0.6393389105796814),
#  ('senhor', 0.6037132143974304),
#  ('cristo', 0.5999789834022522),
#  ('orar', 0.5988916754722595),
#  ('ceus', 0.5961741209030151),
#  ('oracao', 0.589393138885498),
#  ('paz', 0.5810234546661377),
#  ('ti', 0.580318808555603),
#  ('coracao', 0.5780038237571716)]

# %%
def vectorize_text(model, text, method='mean'):
        """
        Convert all words in a text to their embedding vector
        and calculate a vector for the text, by the mean or the sum of word vectors
        Parameters
        ----------
        text: str
        Text from wich the word vector's will be calculated    
        
        method: str
        'mean' or 'sum'
            
        Returns
        -------
        vec: numpy.ndarray 
        Array of the word embeddings from the given text 
        """
        n = model.vector_size
        X = np.empty(shape=[0, n])
        words = text.split()
        for word in words:
            try:
                vec = model[word]
                X = np.append(X,[vec], axis = 0)
            # if oov:    
            except:
                #print('word not in vocabulary: ', word)
                continue
        if X.size == 0:
            vec = np.zeros(n)
        elif method == 'mean':
            vec = np.mean(X,axis=0)
        elif method == 'sum':
            vec = np.sum(X,axis=0)
        return vec
    
def vectorize_corpus(model, corpus, method='mean'):
        """
        Convert all texts in a corpus to vectors
        Parameters
        ----------
        corpus: list
        List of texts    
        
        method: str
        'mean' or 'sum'
            
        Returns
        -------
        X: numpy.ndarray 
        2D Array of vectors from each text in corpus
        """
        X = [vectorize_text(model, text, method=method) for text in corpus]
        X = np.concatenate(X, axis=0).reshape(len(X),len(X[0]))
        return X

x = vectorize_corpus(w2v, 'bolsonaro é um prego')
x
# Out:
# /home/cabral/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:23: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# array([[ 0.76043952,  0.88879251, -0.90697527, ...,  2.15013814,
#          0.7196781 ,  0.28560203],
#        [ 3.00207233, -4.6533699 , -0.19180547, ..., -0.1885826 ,
#         -1.59377575,  0.92375523],
#        [-0.58913201,  0.45220304,  0.12042369, ...,  2.04464436,
#          0.13235311, -0.52890253],
#        ...,
#        [-0.42522535, -0.17314038, -0.21733224, ...,  0.18411075,
#          0.0935633 , -0.13170595],
#        [-0.26353815,  0.03204688, -0.65704316, ..., -0.42762509,
#         -1.10094047, -0.71728772],
#        [ 3.00207233, -4.6533699 , -0.19180547, ..., -0.1885826 ,
#         -1.59377575,  0.92375523]])

# %%
X_train = vectorize_corpus(w2v,X_train_texts)
X_test = vectorize_corpus(w2v,X_test_texts)
# Out:
# /home/cabral/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:23: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
print('logistic regression + w2v')
clf = LogisticRegression()
clf.fit(X_train, y_train)
y_prob = clf.predict_proba(X_test)[:,1]
y_prob_train = clf.predict_proba(X_train)[:,1]
thr = optimal_threshold(y_prob_train,y_train)
print(thr)
y_pred = [1 if p >= thr else 0 for p in y_prob]
test_metrics = get_test_metrics(y_test, y_pred, y_prob, full_metrics = True)
# Out:
# logistic regression + w2v
# 0.46
#               precision    recall  f1-score   support
#
#            0       0.68      0.65      0.66       655
#            1       0.69      0.72      0.70       703
#
#     accuracy                           0.68      1358
#    macro avg       0.68      0.68      0.68      1358
# weighted avg       0.68      0.68      0.68      1358
#
# AUC:  0.7441738242863192

# %%
print('mlp + w2v')
# clf = MLPClassifier(activation = 'relu', solver = 'adam',random_state = 42, 
#                    tol = 1e-3, verbose = True, early_stopping = True, 
#                    n_iter_no_change = 3, max_iter = 100,
#                    hidden_layer_sizes = (100,), alpha = .00001, 
#                    learning_rate_init = .0001, batch_size = 32)
# hl,bs,al,lri = random_search_mlp(X_train_topics,y_train,n_iter)
# clf = optimized_mlp(hl,bs,al,lri)

# results = train_test(clf,X_train_topics,X_test_topics,y_train,y_test)

hl,bs,al,lri = random_search_mlp(X_train,y_train,n_iter=20)
clf = optimized_mlp(hl,bs,al,lri)
clf.fit(X_train,y_train)
y_prob = clf.predict_proba(X_test)[:,1]
y_prob_train = clf.predict_proba(X_train)[:,1]
thr = optimal_threshold(y_prob_train,y_train)
print(thr)
y_pred = [1 if p >= thr else 0 for p in y_prob]
test_metrics = get_test_metrics(y_test, y_pred, y_prob, full_metrics = True)
# Out:
# mlp + w2v
# 0
# hidden layers: (150,); alpha: 0.00238; learning rate: 0.03748; batch: 100
# AUC: 0.877
# 1
# hidden layers: (75, 125); alpha: 0.00002; learning rate: 0.00015; batch: 250
# AUC: 0.885
# 2
# hidden layers: (50, 175, 200); alpha: 0.00013; learning rate: 0.00506; batch: 300
# AUC: 0.878
# 3
# hidden layers: (350, 225); alpha: 0.00000; learning rate: 0.00011; batch: 200
# AUC: 0.911
# 4
# hidden layers: (25, 75); alpha: 0.00008; learning rate: 0.02528; batch: 300
# AUC: 0.886
# 5
# hidden layers: (200, 25, 50); alpha: 0.00000; learning rate: 0.06823; batch: 150
# AUC: 0.874
# 6
# hidden layers: (200,); alpha: 0.00001; learning rate: 0.02102; batch: 250
# AUC: 0.897
# 7
# hidden layers: (25, 25, 125); alpha: 0.00030; learning rate: 0.00686; batch: 250
# AUC: 0.892
# 8
# hidden layers: (125, 250); alpha: 0.00006; learning rate: 0.00691; batch: 100
# AUC: 0.877
# 9
# hidden layers: (200, 250); alpha: 0.00757; learning rate: 0.00911; batch: 200
# AUC: 0.887
# 10
# hidden layers: (75, 300, 25); alpha: 0.00002; learning rate: 0.00123; batch: 100
# AUC: 0.912
# 11
# hidden layers: (125, 300, 125); alpha: 0.00685; learning rate: 0.00909; batch: 250
# AUC: 0.891
# 12
# hidden layers: (125,); alpha: 0.00021; learning rate: 0.00175; batch: 250
# AUC: 0.914
# 13
# hidden layers: (200, 350, 150); alpha: 0.00042; learning rate: 0.00026; batch: 100
# AUC: 0.908
# 14
# hidden layers: (150,); alpha: 0.00000; learning rate: 0.00739; batch: 250
# AUC: 0.910
# 15
# hidden layers: (25, 350, 100); alpha: 0.00007; learning rate: 0.08517; batch: 300
# AUC: 0.792
# 16
# hidden layers: (25, 275); alpha: 0.00001; learning rate: 0.00023; batch: 200
# AUC: 0.881
# 17
# hidden layers: (250, 75, 100); alpha: 0.00471; learning rate: 0.00045; batch: 200
# AUC: 0.914
# 18
# hidden layers: (50,); alpha: 0.00011; learning rate: 0.05626; batch: 150
# AUC: 0.873
# 19
# hidden layers: (125, 275); alpha: 0.00001; learning rate: 0.00011; batch: 150
# AUC: 0.912
#
# --------------------
# BEST PARAMETERS (validation AUC = 0.914)
# hidden layers: (125,); alpha: 0.00021; learning rate: 0.00175; batch: 250
# --------------------
# 0.57
#               precision    recall  f1-score   support
#
#            0       0.73      0.73      0.73       655
#            1       0.75      0.74      0.75       703
#
#     accuracy                           0.74      1358
#    macro avg       0.74      0.74      0.74      1358
# weighted avg       0.74      0.74      0.74      1358
#
# AUC:  0.8257913196442728

# %% [markdown]
# # Doc2Vec

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

documents = [TaggedDocument(doc, [i]) for i, doc in enumerate(corpus)]
model = Doc2Vec(documents, vector_size=100, window=2, min_count=1, workers=4)
model.save('data/2018/doc2vec.model')

doc2vec = Word2Vec.load("data/2018/doc2vec.model")

# %%
doc2vec.infer_vector(['bolsonaro','meu','ovo'])
# Out:
# array([-6.6602312e-02, -3.4949172e-02, -4.9710464e-02, -4.2498123e-02,
#        -1.2360432e-02,  1.3445731e-02,  6.4053880e-03, -2.5431946e-02,
#        -1.3398189e-02,  3.2861233e-02,  1.9098092e-02, -2.7876189e-02,
#         6.3099982e-03, -3.1566672e-02, -3.1930435e-02, -1.0488373e-02,
#        -4.1927681e-03,  1.5584757e-02, -7.0700116e-05, -3.9354652e-02,
#        -1.0245880e-02,  1.4009416e-02,  4.0548917e-02,  3.9947737e-02,
#         8.7503903e-03, -2.1188991e-02, -5.8014154e-02,  1.2945187e-03,
#        -8.7645007e-03,  2.9913289e-03,  1.0643284e-02,  2.2884613e-02,
#        -1.0495075e-02,  6.5721613e-03,  3.7700005e-02, -4.1312732e-02,
#        -1.1737006e-02,  3.6062714e-02,  4.1949291e-02, -5.9720329e-03,
#        -3.1339686e-04,  1.1771470e-02, -1.9825641e-02, -3.3737447e-02,
#        -3.6152098e-02,  5.4852455e-03, -1.1186537e-02, -4.1857189e-03,
#         1.6273582e-02,  2.3028158e-02, -3.7187722e-02,  1.7717843e-03,
#         9.8573705e-03, -1.4747194e-03, -1.8118804e-02, -9.9917008e-03,
#         7.9114266e-02,  2.5185125e-02,  3.2105748e-02,  2.9002046e-02,
#        -3.3881139e-02,  3.8939767e-02, -4.5146145e-02, -9.6035475e-04,
#         2.0776840e-02,  4.5196731e-02,  1.6802277e-02,  4.1955862e-02,
#        -1.6379938e-02, -3.4112148e-02, -1.1953178e-02, -5.5292654e-03,
#         3.4593761e-02,  7.7431984e-03,  2.1760404e-02,  3.0287530e-03,
#        -4.7964144e-02, -5.2649092e-02,  1.6289048e-02, -3.7576687e-03,
#        -4.0955864e-02,  6.6893883e-03, -1.5387614e-02,  5.3671054e-03,
#         1.8872080e-02, -1.1896469e-02, -3.5388086e-02,  2.1346731e-02,
#         1.0761085e-03, -1.1721552e-02, -3.0168286e-02, -4.2811297e-02,
#         1.4305680e-02, -5.6280609e-02,  7.7862092e-03,  1.1857722e-02,
#         5.5027376e-03,  1.8209230e-02, -5.2753040e-03, -2.9685944e-02],
#       dtype=float32)

# %%
def vectorize_doc2vec(model,text):
    text = text.split()
    vector = model.infer_vector(text)
    return vector

def vectorize_corpus_doc2vec(model,corpus):
    X = [vectorize_doc2vec(model, text) for text in corpus]
    X = np.concatenate(X, axis=0).reshape(len(X),len(X[0]))
    return X

X_train = vectorize_corpus_doc2vec(doc2vec, X_train_texts)
X_test = vectorize_corpus_doc2vec(doc2vec, X_test_texts)

# %%
print('logistic regression + doc2vec')
clf = LogisticRegression()
clf.fit(X_train,y_train)
y_prob = clf.predict_proba(X_test)[:,1]
y_prob_train = clf.predict_proba(X_train)[:,1]
thr = optimal_threshold(y_prob_train,y_train)
y_pred = [1 if p >= thr else 0 for p in y_prob]
get_test_metrics(y_test, y_pred, y_prob, full_metrics = True)
# Out:
# logistic regression + doc2vec
#               precision    recall  f1-score   support
#
#            0       0.62      0.68      0.65       655
#            1       0.68      0.62      0.65       703
#
#     accuracy                           0.65      1358
#    macro avg       0.65      0.65      0.65      1358
# weighted avg       0.65      0.65      0.65      1358
#
# AUC:  0.7228323542505946
# (0.6487481590574374,
#  0.67601246105919,
#  0.6520787746170679,
#  0.6173541963015647,
#  0.6520787746170679,
#  0.645353159851301,
#  0.6520787746170679,
#  0.7228323542505946)

# %%
print('mlp + doc2vec')
# clf = MLPClassifier(activation = 'relu', solver = 'adam',random_state = 42, 
#                    tol = 1e-3, verbose = True, early_stopping = True, 
#                    n_iter_no_change = 3, max_iter = 100,
#                    hidden_layer_sizes = (100,), alpha = .00001, 
#                    learning_rate_init = .0001, batch_size = 32)
# hl,bs,al,lri = random_search_mlp(X_train_topics,y_train,n_iter)
# clf = optimized_mlp(hl,bs,al,lri)

# results = train_test(clf,X_train_topics,X_test_topics,y_train,y_test)

hl,bs,al,lri = random_search_mlp(X_train,y_train,n_iter=50)
clf = optimized_mlp(hl,bs,al,lri)
clf.fit(X_train,y_train)
y_prob = clf.predict_proba(X_test)[:,1]
y_prob_train = clf.predict_proba(X_train)[:,1]
thr = optimal_threshold(y_prob_train,y_train)
print(thr)
y_pred = [1 if p >= thr else 0 for p in y_prob]
test_metrics = get_test_metrics(y_test, y_pred, y_prob, full_metrics = True)
# Out:
# mlp + doc2vec
# 0
# hidden layers: (150,); alpha: 0.00238; learning rate: 0.03748; batch: 100
# AUC: 0.865
# 1
# hidden layers: (75, 125); alpha: 0.00002; learning rate: 0.00015; batch: 250
# AUC: 0.848
# 2
# hidden layers: (50, 175, 200); alpha: 0.00013; learning rate: 0.00506; batch: 300
# AUC: 0.864
# 3
# hidden layers: (350, 225); alpha: 0.00000; learning rate: 0.00011; batch: 200
# AUC: 0.884
# 4
# hidden layers: (25, 75); alpha: 0.00008; learning rate: 0.02528; batch: 300
# AUC: 0.859
# 5
# hidden layers: (200, 25, 50); alpha: 0.00000; learning rate: 0.06823; batch: 150
# AUC: 0.837
# 6
# hidden layers: (200,); alpha: 0.00001; learning rate: 0.02102; batch: 250
# AUC: 0.873
# 7
# hidden layers: (25, 25, 125); alpha: 0.00030; learning rate: 0.00686; batch: 250
# AUC: 0.869
# 8
# hidden layers: (125, 250); alpha: 0.00006; learning rate: 0.00691; batch: 100
# AUC: 0.869
# 9
# hidden layers: (200, 250); alpha: 0.00757; learning rate: 0.00911; batch: 200
# AUC: 0.863
# 10
# hidden layers: (75, 300, 25); alpha: 0.00002; learning rate: 0.00123; batch: 100
# AUC: 0.873
# 11
# hidden layers: (125, 300, 125); alpha: 0.00685; learning rate: 0.00909; batch: 250
# AUC: 0.879
# 12
# hidden layers: (125,); alpha: 0.00021; learning rate: 0.00175; batch: 250
# AUC: 0.882
# 13
# hidden layers: (200, 350, 150); alpha: 0.00042; learning rate: 0.00026; batch: 100
# AUC: 0.886
# 14
# hidden layers: (150,); alpha: 0.00000; learning rate: 0.00739; batch: 250
# AUC: 0.885
# 15
# hidden layers: (25, 350, 100); alpha: 0.00007; learning rate: 0.08517; batch: 300
# AUC: 0.817
# 16
# hidden layers: (25, 275); alpha: 0.00001; learning rate: 0.00023; batch: 200
# AUC: 0.856
# 17
# hidden layers: (250, 75, 100); alpha: 0.00471; learning rate: 0.00045; batch: 200
# AUC: 0.871
# 18
# hidden layers: (50,); alpha: 0.00011; learning rate: 0.05626; batch: 150
# AUC: 0.857
# 19
# hidden layers: (125, 275); alpha: 0.00001; learning rate: 0.00011; batch: 150
# AUC: 0.862
# 20
# hidden layers: (25,); alpha: 0.00232; learning rate: 0.00062; batch: 150
# AUC: 0.807
# 21
# hidden layers: (325,); alpha: 0.00207; learning rate: 0.00010; batch: 300
# AUC: 0.829
# 22
# hidden layers: (100, 75, 300); alpha: 0.00706; learning rate: 0.00056; batch: 200
# AUC: 0.862
# 23
# hidden layers: (275,); alpha: 0.00019; learning rate: 0.00047; batch: 250
# AUC: 0.846
# 24
# hidden layers: (25, 125); alpha: 0.00821; learning rate: 0.00022; batch: 300
# AUC: 0.686
# 25
# hidden layers: (350, 300); alpha: 0.00335; learning rate: 0.00554; batch: 300
# AUC: 0.881
# 26
# hidden layers: (250, 25, 325); alpha: 0.00044; learning rate: 0.00398; batch: 200
# AUC: 0.878
# 27
# hidden layers: (225, 25); alpha: 0.00030; learning rate: 0.00266; batch: 300
# AUC: 0.886
# 28
# hidden layers: (200, 225); alpha: 0.00003; learning rate: 0.01768; batch: 50
# AUC: 0.864
# 29
# hidden layers: (300, 175, 350); alpha: 0.00023; learning rate: 0.00528; batch: 250
# AUC: 0.881
# 30
# hidden layers: (350,); alpha: 0.00002; learning rate: 0.00046; batch: 200
# AUC: 0.860
# 31
# hidden layers: (325, 175, 100); alpha: 0.00370; learning rate: 0.02622; batch: 200
# AUC: 0.886
# 32
# hidden layers: (300,); alpha: 0.00476; learning rate: 0.01389; batch: 200
# AUC: 0.849
# 33
# hidden layers: (350, 325); alpha: 0.00297; learning rate: 0.00031; batch: 200
# AUC: 0.892
# 34
# hidden layers: (200, 150); alpha: 0.00247; learning rate: 0.02642; batch: 300
# AUC: 0.873
# 35
# hidden layers: (250, 250); alpha: 0.00003; learning rate: 0.00182; batch: 150
# AUC: 0.890
# 36
# hidden layers: (100,); alpha: 0.00798; learning rate: 0.03693; batch: 300
# AUC: 0.869
# 37
# hidden layers: (150, 50); alpha: 0.00000; learning rate: 0.00366; batch: 100
# AUC: 0.867
# 38
# hidden layers: (225, 125); alpha: 0.00000; learning rate: 0.00246; batch: 300
# AUC: 0.887
# 39
# hidden layers: (25, 225, 350); alpha: 0.00000; learning rate: 0.00031; batch: 50
# AUC: 0.868
# 40
# hidden layers: (125,); alpha: 0.00001; learning rate: 0.06348; batch: 250
# AUC: 0.866
# 41
# hidden layers: (350, 50, 50); alpha: 0.00002; learning rate: 0.00157; batch: 300
# AUC: 0.883
# 42
# hidden layers: (150, 150, 325); alpha: 0.00019; learning rate: 0.00227; batch: 200
# AUC: 0.885
# 43
# hidden layers: (200, 200); alpha: 0.00000; learning rate: 0.00201; batch: 150
# AUC: 0.873
# 44
# hidden layers: (300,); alpha: 0.00030; learning rate: 0.00424; batch: 300
# AUC: 0.878
# 45
# hidden layers: (250, 75); alpha: 0.00007; learning rate: 0.00407; batch: 200
# AUC: 0.861
# 46
# hidden layers: (250, 275); alpha: 0.00001; learning rate: 0.00976; batch: 150
# AUC: 0.870
# 47
# hidden layers: (225,); alpha: 0.00108; learning rate: 0.00091; batch: 50
# AUC: 0.880
# 48
# hidden layers: (300,); alpha: 0.00002; learning rate: 0.00362; batch: 50
# AUC: 0.878
# 49
# hidden layers: (200,); alpha: 0.00005; learning rate: 0.04529; batch: 50
# AUC: 0.849
#
# --------------------
# BEST PARAMETERS (validation AUC = 0.892)
# hidden layers: (350, 325); alpha: 0.00297; learning rate: 0.00031; batch: 200
# --------------------
# 0.53
#               precision    recall  f1-score   support
#
#            0       0.71      0.71      0.71       655
#            1       0.73      0.73      0.73       703
#
#     accuracy                           0.72      1358
#    macro avg       0.72      0.72      0.72      1358
# weighted avg       0.72      0.72      0.72      1358
#
# AUC:  0.8043999001009849

# %% [markdown]
# # Test model with messages about covid-19 collected from WhatsApp in 2020

# %%
df_2020 = pd.read_csv('data/2020/FakeWhatsApp2020.csv')
print('orignal size',len(df_2020))

df_2020 = df_2020.dropna(subset=['misinformation','text'])
df_2020['types'] = [len(set(t.split())) for t in df_2020['text']]
df_2020 = df_2020[(df_2020['types']>15) & (df_2020['revision']!=1)]
print('size after filtering',len(df_2020))
df_2020.head()
# Out:
# orignal size 2899
# size after filtering 1261
#    shares                                               text  misinformation  \
# 0      27  O ministro da Ciência, Tecnologia, Inovações e...               0
# 1      26  Pesquisa com mais de 6.000 médicos em 30 paíse...               1
# 2      25  É com muita alegria que comunico que mais um p...               0
# 3      25  Renda Brasil unificará vários programas sociai...               0
# 5      24  “O que mais queremos é voltar à normalidade, e...               0
#
#                                               source  revision  types
# 0  https://www.gov.br/pt-br/noticias/educacao-e-p...       NaN     61
# 1  https://www.aosfatos.org/noticias/e-falso-que-...       NaN     19
# 2  http://portal.mec.gov.br/component/content/art...       NaN     77
# 3  https://agenciabrasil.ebc.com.br/politica/noti...       NaN     50
# 5                                                NaN       NaN     64

# %%
texts_test = [preprocess(t, lemma = True) for t in df_2020['text']]
y_test = df_2020['misinformation']

# %%
print_class_balance(y_test)

# %%
texts_train = df['preprocessed_text_lemma']
#target
y_train = df['misinformation']

# %%
#vectorizer = TfidfVectorizer(max_features = None, ngram_range = (2,2), lowercase = True, token_pattern = r'[^\s]+')
vectorizer = CountVectorizer(max_features = None, ngram_range = (1,3), #(1,3) 
                             lowercase = False, token_pattern = r'[^\s]+',binary=True)
vectorizer.fit(texts_train)   
X_train = vectorizer.transform(texts_train)
X_test = vectorizer.transform(texts_test)
X_train.shape
# Out:
# (6790, 375893)

# %%
print('logistic regression + binary bow')
clf = LogisticRegression()
clf.fit(X_train,y_train)

y_prob = clf.predict_proba(X_test)[:,1]
y_prob_train = clf.predict_proba(X_train)[:,1]
# threshold moving

#thr = optimal_threshold(y_prob,y_test)
thr = optimal_threshold(y_prob_train,y_train)
print(thr)
y_pred = [1 if p >= thr else 0 for p in y_prob]
get_test_metrics(y_test, y_pred, y_prob, full_metrics = True)
# Out:
# logistic regression + binary bow
# 0.42
#               precision    recall  f1-score   support
#
#            0       0.73      0.82      0.77       734
#            1       0.70      0.57      0.63       527
#
#     accuracy                           0.72      1261
#    macro avg       0.72      0.70      0.70      1261
# weighted avg       0.72      0.72      0.71      1261
#
# AUC:  0.7822800386745188
# (0.7200634417129262,
#  0.7013888888888888,
#  0.7741522712731925,
#  0.5749525616698292,
#  0.7741522712731925,
#  0.6319082377476538,
#  0.7741522712731925,
#  0.7822800386745188)
